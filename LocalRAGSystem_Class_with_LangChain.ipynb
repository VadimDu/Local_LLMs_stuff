# %% [markdown]
# # RAG implementation with LangChain framework with local LLMs - complete class
#
# In this notebook I create Retrieval-Augmented Generation (RAG) system based on my documents (some scientific papers) for by local LLMs implemented with LangChain framework
#
# __What is RAG?__
#
# Retrieval-Augmented Generation (RAG) is an architecture that augments a foundation LLM with external, up-to-date knowledge via a retrieval step before generation. It decouples the LLM's static training data from dynamic, domain-specific information.
#
# __Core Components (Local Setup):__
#
# * Vector Database: Stores embeddings of external documents (e.g., ChromaDB, FAISS, Weaviate).
#
# * Embedding Model: Converts text → dense vectors (e.g., all-MiniLM-L6-v2, BGE-small).
#
# * Retriever: Queries the DB for top-k relevant passages via similarity search (e.g., cosine distance).
#
# * LLM: Takes the retrieved context + user query → generates a truth/fact-grounded response.
#
#
# __This notebook builds on the previous RAG-LangChain notebook by encapsulating all the separate steps, functions and my trials into a single, concise and re-usable Class.__
#
# _Note: There are still some improvements to apply, but overall it works great!_

# %% [markdown]
# ## Complete RAG implementation with LangChain, ChromaDB, and options for local LLMs
# The solution supports document updates, multiple file types, various retrievers, and flexible LLM integration, all wrapped in a dedicted Class.

# %% [markdown]
# ### Small example of using sentence embedding models

# %%
from sentence_transformers import SentenceTransformer
from sentence_transformers.util import cos_sim

# Manual loading of the new Qwen3-0.6B embedding model via Transformers
# from sentence_transformers import SentenceTransformer
# model = SentenceTransformer("Qwen/Qwen3-Embedding-0.6B")
# # Not working at the moment:
# #ValueError: The checkpoint you are trying to load has model type `qwen3` but Transformers does not recognize this architecture. This could be because of an issue with the checkpoint, or because your version of Transformers is out of date.

# Mixedbread-ai/mxbai-embed-large-v1 embedding model
model = SentenceTransformer("mixedbread-ai/mxbai-embed-large-v1")

# %%
# The prompt used for query retrieval tasks:
# query_prompt = 'Represent this sentence for searching relevant passages: '
query = "A man is eating a piece of bread"
docs = [
    "A man is eating food.",
    "A man is eating pasta.",
    "The girl is carrying a baby.",
    "A man is riding a horse.",
]

# %%
query_embedding = model.encode(query, prompt_name="query")
# query_embedding = model.encode(query, prompt=query_prompt)
docs_embeddings = model.encode(docs)

similarities = cos_sim(query_embedding, docs_embeddings)
print('similarities:', similarities)
# Out:
# similarities: tensor([[0.7920, 0.6369, 0.1651, 0.3621]])

# %% [markdown]
# ### Imports & Configs

# %%
my_llms = {'qwen3-coder': 'qwen3-coder-30b-a3b-instruct', 
           'qwen3-thinking': 'qwen3-30b-a3b-thinking-2507',
           'glm-4.5-air': 'glm-4.5-air',
           'glm-4.5-air-m': 'glm-4.5-air-mlx',
           'glm-4.5-air-5': 'glm-4.5-air@5bit',
           'gpt-oss': 'gpt-oss-120b',
           'gpt-oss-us': 'unsloth/gpt-oss-120b',
           }

# %%
import os
from pathlib import Path
from typing import List, Dict, Union
import torch
import chromadb

# LangChain/Document Processing Imports
from langchain.document_loaders import (
    DirectoryLoader,
    TextLoader,
    PyPDFLoader,
    UnstructuredMarkdownLoader,
    Docx2txtLoader
)
from langchain_community.document_loaders import Docx2txtLoader

from langchain import hub
from langchain.docstore.document import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.chat_models import ChatOpenAI

# ChromaDB Vector Store
from langchain.vectorstores import Chroma
from langchain.embeddings import HuggingFaceEmbeddings, OpenAIEmbeddings

# Retrievers
from langchain.retrievers import BM25Retriever, EnsembleRetriever
from langchain.memory import ConversationBufferMemory

# LLM Integration
from langchain.llms import HuggingFacePipeline, OpenAI
from langchain.chains import RetrievalQA, ConversationalRetrievalChain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain.chains.retrieval import create_retrieval_chain

# Prompts
from langchain.prompts import ChatPromptTemplate, PromptTemplate


workdir = Path.home()/"Downloads"/"RAG_personal_knowledge_base"

# Configuration of embdedding and LLM models
PERSIST_DIR = str(workdir/"chroma_db_mxbai-embed-large-v1")
#EMBEDDING_MODEL = "BAAI/bge-small-en-v1.5"
EMBEDDING_MODEL = "mixedbread-ai/mxbai-embed-large-v1"
BASE_URL = "http://localhost:1234/v1"  # LM-Studio local API
API_KEY = "not-needed"

LLM_CONFIG = {
    "provider": "lmstudio",  # Options: "openai", "huggingface", "lmstudio"
    "model_name": my_llms['gpt-oss-us'],
    "openai_api_key": API_KEY,
    "lmstudio_url": BASE_URL
}

# device setup
if torch.backends.mps.is_available():
    DEVICE = torch.device("mps")
else:
    DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {DEVICE}")
# Out:
# Using device: mps

# %%
# Example of which keys PromptTemplate and ChatPromptTemplate have
prompttemplate = hub.pull("hwchase17/react")
chatprompttemplate = hub.pull("hwchase17/openai-tools-agent")
print(f'How PromptTemplate looks:\n{prompttemplate}\n')
print(f'How ChatPromptTemplate looks:\n{chatprompttemplate}\n')
# Out:
# /opt/homebrew/lib/python3.12/site-packages/langsmith/client.py:272: LangSmithMissingAPIKeyWarning: API key must be provided when using hosted LangSmith API
#   warnings.warn(
# /opt/homebrew/lib/python3.12/site-packages/langsmith/client.py:272: LangSmithMissingAPIKeyWarning: API key must be provided when using hosted LangSmith API
#   warnings.warn(
# How PromptTemplate looks:
# input_variables=['agent_scratchpad', 'input', 'tool_names', 'tools'] input_types={} partial_variables={} metadata={'lc_hub_owner': 'hwchase17', 'lc_hub_repo': 'react', 'lc_hub_commit_hash': 'd15fe3c426f1c4b3f37c9198853e4a86e20c425ca7f4752ec0c9b0e97ca7ea4d'} template='Answer the following questions as best you can. You have access to the following tools:\n\n{tools}\n\nUse the following format:\n\nQuestion: the input question you must answer\nThought: you should always think about what to do\nAction: the action to take, should be one of [{tool_names}]\nAction Input: the input to the action\nObservation: the result of the action\n... (this Thought/Action/Action Input/Observation can repeat N times)\nThought: I now know the final answer\nFinal Answer: the final answer to the original input question\n\nBegin!\n\nQuestion: {input}\nThought:{agent_scratchpad}'
#
# How ChatPromptTemplate looks:
# input_variables=['agent_scratchpad', 'input'] optional_variables=['chat_history'] input_types={'chat_history': list[typing.Annotated[typing.Union[typing.Annotated[langchain_core.messages.ai.AIMessage, Tag(tag='ai')], typing.Annotated[langchain_core.messages.human.HumanMessage, Tag(tag='human')], typing.Annotated[langchain_core.messages.chat.ChatMessage, Tag(tag='chat')], typing.Annotated[langchain_core.messages.system.SystemMessage, Tag(tag='system')], typing.Annotated[langchain_core.messages.function.FunctionMessage, Tag(tag='function')], typing.Annotated[langchain_core.messages.tool.ToolMessage, Tag(tag='tool')], typing.Annotated[langchain_core.messages.ai.AIMessageChunk, Tag(tag='AIMessageChunk')], typing.Annotated[langchain_core.messages.human.HumanMessageChunk, Tag(tag='HumanMessageChunk')], typing.Annotated[langchain_core.messages.chat.ChatMessageChunk, Tag(tag='ChatMessageChunk')], typing.Annotated[langchain_core.messages.system.SystemMessageChunk, Tag(tag='SystemMessageChunk')], typing.Annotated[langchain_core.messages.function.FunctionMessageChunk, Tag(tag='FunctionMessageChunk')], typing.Annotated[langchain_core.messages.tool.ToolMessageChunk, Tag(tag='ToolMessageChunk')]], FieldInfo(annotation=NoneType, required=True, discriminator=Discriminator(discriminator=<function _get_type at 0x149509940>, custom_error_type=None, custom_error_message=None, custom_error_context=None))]], 'agent_scratchpad': list[typing.Annotated[typing.Union[typing.Annotated[langchain_core.messages.ai.AIMessage, Tag(tag='ai')], typing.Annotated[langchain_core.messages.human.HumanMessage, Tag(tag='human')], typing.Annotated[langchain_core.messages.chat.ChatMessage, Tag(tag='chat')], typing.Annotated[langchain_core.messages.system.SystemMessage, Tag(tag='system')], typing.Annotated[langchain_core.messages.function.FunctionMessage, Tag(tag='function')], typing.Annotated[langchain_core.messages.tool.ToolMessage, Tag(tag='tool')], typing.Annotated[langchain_core.messages.ai.AIMessageChunk, Tag(tag='AIMessageChunk')], typing.Annotated[langchain_core.messages.human.HumanMessageChunk, Tag(tag='HumanMessageChunk')], typing.Annotated[langchain_core.messages.chat.ChatMessageChunk, Tag(tag='ChatMessageChunk')], typing.Annotated[langchain_core.messages.system.SystemMessageChunk, Tag(tag='SystemMessageChunk')], typing.Annotated[langchain_core.messages.function.FunctionMessageChunk, Tag(tag='FunctionMessageChunk')], typing.Annotated[langchain_core.messages.tool.ToolMessageChunk, Tag(tag='ToolMessageChunk')]], FieldInfo(annotation=NoneType, required=True, discriminator=Discriminator(discriminator=<function _get_type at 0x149509940>, custom_error_type=None, custom_error_message=None, custom_error_context=None))]]} partial_variables={'chat_history': []} metadata={'lc_hub_owner': 'hwchase17', 'lc_hub_repo': 'openai-tools-agent', 'lc_hub_commit_hash': 'c18672812789a3b9697656dd539edf0120285dcae36396d0b548ae42a4ed66f5'} messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are a helpful assistant'), additional_kwargs={}), MessagesPlaceholder(variable_name='chat_history', optional=True), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={}), MessagesPlaceholder(variable_name='agent_scratchpad')]

# %% [markdown]
# ### RAG Class implementation

# %%
class LocalRAGSystem:

    def __init__(self, persist_dir: str = PERSIST_DIR, 
                 embedding_model_name: str = EMBEDDING_MODEL):
        """
        Initialize the local RAG system with Chroma vector store, embedding model and local LLM, plus all configuration parameters.
        """

        self.persist_dir = persist_dir
        self.embedding_model_name = embedding_model_name
        self.CHUNK_SIZE_THRESHOLD = 1200

        # Initialize embedding model (runs locally)
        self.embeddings = HuggingFaceEmbeddings(  # HuggingFace sentence_transformers embedding models
            model_name=self.embedding_model_name,
            model_kwargs={'device': DEVICE},
            encode_kwargs={
            'normalize_embeddings': True,  # Crucial for cosine similarity
            'batch_size': 32,  # Batch processing speedup
            'dtype': torch.float32  # (fp32), can also use: torch.bfloat16,
        })

        # Initialize local LLM with OpenAI-compatible API (LM-Studio)
        self.llm = ChatOpenAI(
            model_name=LLM_CONFIG["model_name"],
            openai_api_key=LLM_CONFIG["openai_api_key"],
            openai_api_base=LLM_CONFIG["lmstudio_url"],
            temperature=1, # 0.7 for most models, for gpt-oss 1 is recommended
            max_tokens=32000,
        )

        # Initialize Chroma vector store
        if os.path.exists(self.persist_dir) and bool(os.listdir(self.persist_dir)):
            print("Loading existing vector store...")
            try:
                self.vectordb = Chroma(
                    persist_directory=self.persist_dir,
                    embedding_function=self.embeddings,
                    collection_name="personal_knowledge"
                )
                self.split_docs = None
                # Check available collections
                client = chromadb.PersistentClient(path=self.persist_dir)
                print(f'Available collections in ChromaDB: {client.list_collections()}')
            except Exception as e:
                print(f"Error loading existing vector store: {e}")

        else:
            print("No existing vector store found.")


    def load_documents(self, source_dir: Union[str, Path]) -> List[Dict]:
        """Load documents from directory with multiple file support"""

        source_dir = Path(source_dir)
        if not source_dir.exists():
            print(f"Source directory does not exist: {source_dir}")
            return []
        print(f'Contents of the documents dir: {list(source_dir.glob("**/*"))}')

        # Define loaders for different file types
        loaders = {
            ".txt": TextLoader,
            ".md": UnstructuredMarkdownLoader,
            ".pdf": PyPDFLoader,
            ".docx": Docx2txtLoader,
        }

        documents = []
        for ext, loader_class in loaders.items():
            files = list(source_dir.glob(f"**/*{ext}"))
            if files:
                loader = DirectoryLoader(
                    str(source_dir),
                    glob=f"**/*{ext}",
                    loader_cls=loader_class,
                    show_progress=True
                )
                documents.extend(loader.load())
                print(f"Loaded {len(loader.load())} pages")

        return documents
    

    def chunk_docs(self, docs: List[Document]) -> List[Document]:
        """
        Split documents into smaller chunks for RAG, optimized for LLMs. 
        chunk_size: Max characters per text segment (e.g., 500). Too small: context loss. Too large: LLM overflows/context noise.
        chunk_overlap: Characters reused from previous chunk (e.g., 50). Prevents splitting mid-sentence → preserves context across chunks.
        """

        text_splitter = RecursiveCharacterTextSplitter(
            chunk_size=self.CHUNK_SIZE_THRESHOLD, 
            chunk_overlap=self.CHUNK_SIZE_THRESHOLD/10, # 10-20% overlap
            length_function=len, # Function to measure text length (characters not tokens!)
            is_separator_regex=False,
            separators=["\n\n", "\n", " ", "", "."],
        )
        split_docs = text_splitter.split_documents(docs)
        print(f"Total chunks created: {len(split_docs)}")

        return split_docs


    def build_vector_db_from_docs(self, file_paths: List[str]):
        """Build ChromaDB vector store (persist to disk) with BGE-small embeddings from document chunks."""

        self.documents = self.load_documents(file_paths)
        self.split_docs = self.chunk_docs(self.documents)

        self.vectordb = Chroma.from_documents(
            documents=self.split_docs,
            embedding=self.embeddings,
            persist_directory=self.persist_dir,
            collection_name="personal_knowledge"
        )
        print(f"Vector store persisted at {str(self.persist_dir)}")
        print(f"Added {len(self.split_docs)} documents to vector store")

        return self.vectordb


    def update_vector_db(self, new_docs_path: List[str]):
        """Update existing vector store with new documents"""

        new_documents = self.load_documents(new_docs_path)
        new_split_docs = self.chunk_docs(new_documents)
        print(new_split_docs)

        self.vectordb.add_documents(new_split_docs)
        # texts = [doc.page_content for doc in split_docs]
        # metadatas = [doc.metadata for doc in split_docs]
        # self.vectordb.add_texts(texts=texts, metadatas=metadatas)
        print("\nDatabase updated with new documents")
        self.vectordb.persist()

        return self.vectordb


    def list_existing_documents(self) -> List[str]:
        """
        List all documents (metadata) in the current vector store
        """
        try:
            docs = self.vectordb.get()
            return docs['metadatas'] if docs else []
        except Exception as e:
            print(f"Error listing documents: {e}")
            return []


    def create_retrievers(self):
            """
            Create different types of retrievers
            """

            if self.split_docs is None:
                print("No split documents available for BM25Retriever creation. Need to build vector DB first.")
                # Vector Retriever (semantic search)
                vector_retriever = self.vectordb.as_retriever(
                search_type="similarity",
                search_kwargs={"k": 30}
            )
                return {"vec_semantic": vector_retriever}

            else:
                # BM25 Retriever (for keyword-based search)
                bm25_retriever = BM25Retriever.from_documents(
                    self.split_docs,
                )
                bm25_retriever.k = 30

                # Vector Retriever (semantic search)
                vector_retriever = self.vectordb.as_retriever(
                    search_type="similarity",
                    search_kwargs={"k": 30}
                )

                # Ensemble Retriever combining BM25 and Vector
                ensemble_retriever = EnsembleRetriever(
                    retrievers=[bm25_retriever, vector_retriever],
                    weights=[0.4, 0.6]
                )

                return {
                    "bm25": bm25_retriever,
                    "vec_semantic": vector_retriever,
                    "ensemble": ensemble_retriever
                }


    def build_qa_chain(self,  
              retriever_type: str = "vec_semantic", 
              use_conversation: bool = False):
        """
        Builds a RetrievalQA chain with different retrieval methods, using the given local LLM, vector store and a question template.
        """

        retrievers = self.create_retrievers()

        # template = """
        #             Use ONLY the following context (source documents and metadata) to answer the question. 
        #             Do not use prior knowledge.
        #             If the context doesn't contain the answer, respond with "INSUFFICIENT CONTEXT".

        #             Context: {context}

        #             Question: {question}

        #             Helpful Answer:
        #         """
        # prompt = PromptTemplate.from_template(template)

        # The new implementation
        prompt = ChatPromptTemplate.from_messages(
        [
            ("system",
            '''Use ONLY the following context (source documents and metadata) to answer the question. 
                Do not use prior knowledge.
                If the context doesn't contain the answer, respond with "INSUFFICIENT CONTEXT"'''
             "Context: {context}"),
            ("human", "{question}")
        ])

        if use_conversation:
            memory = ConversationBufferMemory(
                memory_key="chat_history",
                output_key="answer",
                return_messages=True
            )
            conv_chain = ConversationalRetrievalChain.from_llm(
                llm=self.llm,
                retriever=retrievers[retriever_type],
                memory=memory,
                combine_docs_chain_kwargs={"prompt": prompt, 
                    "document_separator": "\n\n"},
                return_source_documents=True,
            )
            return conv_chain

        else:
            qa_chain = RetrievalQA.from_chain_type(
                llm=self.llm,
                chain_type="stuff",  # All context stuffed into prompt
                retriever=retrievers[retriever_type],
                return_source_documents=True,  # For source verification
                chain_type_kwargs={"prompt": prompt,
                    "document_separator": "\n\n"  # Clean context formatting, improves prompt readability for the LLM.
                }
            )
            # # the new LangChain api with "create_*"
            # # “stuff” strategy = concatenate all retrieved chunks
            # combine_chain = create_stuff_documents_chain(self.llm, prompt)
            # retrieval_chain = create_retrieval_chain(
            #     retriever=retrievers[retriever_type],
            #     combine_docs_chain=combine_chain,
            # )
            return qa_chain

# %% [markdown]
# ### Running the complete RAG implementation

# %%
# Initialize the local RAG system, connecting to an existing vector db (if available at PERSIST_DIR)
local_rag_sys = LocalRAGSystem()

# check config setting are correct
print(f'Chroma DB path: {local_rag_sys.persist_dir}')
print(f'Embedding model: {EMBEDDING_MODEL}')
print(f'LLM model: {LLM_CONFIG["model_name"]}')
print(f'Document chunk size: {local_rag_sys.CHUNK_SIZE_THRESHOLD}')
# Out:
# Loading existing vector store...
# Available collections in ChromaDB: [Collection(name=personal_knowledge)]
# Chroma DB path: /Users/danid/Downloads/RAG_personal_knowledge_base/chroma_db_mxbai-embed-large-v1
# Embedding model: mixedbread-ai/mxbai-embed-large-v1
# LLM model: unsloth/gpt-oss-120b
# Document chunk size: 1200

# %%
# List existing documents in the vector store
docs_in_db = local_rag_sys.list_existing_documents()
docs = []
for doc in docs_in_db:
    docs.append(doc['title'])
print(set(docs))  # Display unique document titles in the vector store

# %%
# Build a new vector database from pdf-documents
vectordb = local_rag_sys.build_vector_db_from_docs(file_paths=workdir/"pdfs")
# Out:
# Contents of the documents dir: [PosixPath('/Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/Selection of microorganisms capable of polyethylene (PE) and polypropylene (PP) degradation.pdf'), PosixPath('/Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/.DS_Store'), PosixPath('/Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/Diffusion Sequence Models for Enhanced Protein Representation and Generation.pdf'), PosixPath('/Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/Biodegradation of polyethylene and polypropylene by Lysinibacillus species JJY0216 isolated from soil grove.pdf'), PosixPath('/Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/xTrimoPGLM- unified 100-billion-parameter pretrained transformer for deciphering the language of proteins.pdf'), PosixPath('/Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/SaProt- Protein Language Modeling with Structure-aware Vocabulary.pdf'), PosixPath('/Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/Polyethylene Degradation by a Rhodococcous Strain Isolated from Naturally Weathered Plastic Waste Enrichment .pdf'), PosixPath('/Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/Using artificial intelligence to document the hidden RNA virosphere.pdf')]
# 100%|██████████| 7/7 [00:10<00:00,  1.47s/it]
# 100%|██████████| 7/7 [00:09<00:00,  1.42s/it]
# Loaded 131 pages
# Total chunks created: 528
# Vector store persisted at /Users/danid/Downloads/RAG_personal_knowledge_base/chroma_db_mxbai-embed-large-v1
# Added 528 documents to vector store

# %%
# update the vector db with new documents
vectordb = local_rag_sys.update_vector_db(new_docs_path=workdir/"new_docs_to_add")
# Out:
# Contents of the documents dir: [PosixPath('/Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx')]
# 100%|██████████| 1/1 [00:00<00:00, 109.65it/s]
# 100%|██████████| 1/1 [00:00<00:00, 153.94it/s]
# Loaded 1 pages
# Total chunks created: 56
# [Document(metadata={'source': '/Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx'}, page_content='Genomic and Metabolic Insights into Microbial Biodegradation of TNT\n\n\n\nAbstract'), Document(metadata={'source': '/Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx'}, page_content='Abstract\n\n2,4,6-Trinitrotoluene (TNT) is a recalcitrant explosive pollutant whose breakdown in the environment is facilitated by diverse microbes. This document summarizes key findings on TNT biodegradation, including the spectrum of TNT-transforming bacteria, fungi, and yeasts, the major genes and enzymes driving TNT metabolism, and the primary degradation pathways. Genomic analyses have identified critical catabolic genes (e.g. nitroreductases, oxygen-insensitive reductases of the Old Yellow Enzyme family, and azoreductases) that initiate TNT denitration and ring reduction. Metabolic pathway studies reveal that TNT is usually reduced stepwise to aminodinitrotoluenes and other intermediates, with some microbes forming Meisenheimer complexes leading to denitration. Omics approaches (transcriptomics, proteomics) provide insights into global stress responses and pathway activation in TNT-exposed microbes, highlighting inducible enzymes and regulatory networks. These advances lay the groundwork for biotechnological applications, from engineered microbial consortia to transgenic plants, aimed at efficient TNT bioremediation.\n\n\n\nIntroduction'), Document(metadata={'source': '/Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx'}, page_content='Introduction\n\nTNT as a Contaminant: TNT is a synthetic nitroaromatic explosive widely used in military and industrial applications. Past munitions manufacturing and usage have led to soil and groundwater contamination with TNT, which is toxic, persistent, and classified as a priority pollutant . TNT’s chemical structure (a toluene ring with three electron-withdrawing nitro groups) makes it highly resistant to conventional biodegradation. The nitro substituents strongly deactivate the aromatic ring, hindering direct oxidative attack by typical aromatic-degrading enzymes . Consequently, TNT remains in the environment for long periods, posing health and ecological risks.'), Document(metadata={'source': '/Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx'}, page_content='Microbial Bioremediation: The use of microorganisms to detoxify and remove TNT from the environment offers a promising alternative to costly physicochemical cleanup methods . Certain bacteria and fungi have evolved enzymatic strategies to transform TNT despite its recalcitrance . Microbial TNT biodegradation typically involves reduction of nitro groups and other transformations that render TNT less toxic or more amenable to further breakdown. Over decades of research, numerous TNT-degrading strains have been isolated from soils, compost, and extreme environments, underscoring the metabolic diversity and adaptability of microbes . Understanding the genomics and metabolism of these organisms is crucial for enhancing bioremediation processes.'), Document(metadata={'source': '/Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx'}, page_content='Scope of Document: This document provides a comprehensive analysis of microbial TNT degradation. We first catalog the known TNT-degrading species across bacteria, fungi, and yeasts, highlighting their roles in TNT transformation. We then delve into genomic insights, summarizing key catabolic genes, enzymes, and regulatory elements identified in these organisms. The major meta ...
# Database updated with new documents
# /var/folders/y_/2xtp4jn551g4kc50l69n92dr0000gn/T/ipykernel_90962/1031254841.py:135: LangChainDeprecationWarning: Since Chroma 0.4.x the manual persistence method is no longer supported as docs are automatically persisted.
#   self.vectordb.persist()

# %%
# update the vector db with new documents
vectordb = local_rag_sys.update_vector_db(new_docs_path=workdir/"new_pdfs_to_add")
# Out:
# Contents of the documents dir: [PosixPath('/Users/danid/Downloads/RAG_personal_knowledge_base/new_pdfs_to_add/A marine bacterial community capable of degrading poly(ethylene terephthalate) and polyethylene.pdf')]
# 100%|██████████| 1/1 [00:00<00:00,  4.25it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.76it/s]
# Loaded 12 pages
# Total chunks created: 64
# [Document(metadata={'producer': 'Acrobat Distiller 8.1.0 (Windows)', 'creator': 'Elsevier', 'creationdate': '2021-06-12T16:00:41+00:00', 'moddate': '2021-06-12T16:49:48+00:00', 'title': 'A marine bacterial community capable of degrading poly(ethylene terephthalate) and polyethylene', 'keywords': 'Ocean,Plastics,Bacterial community reconstitution,Degradation,Pollution', 'subject': 'Journal of Hazardous Materials, 416 (2021) 125928. doi:10.1016/j.jhazmat.2021.125928', 'author': 'Rongrong Gao', 'source': '/Users/danid/Downloads/RAG_personal_knowledge_base/new_pdfs_to_add/A marine bacterial community capable of degrading poly(ethylene terephthalate) and polyethylene.pdf', 'total_pages': 12, 'page': 0, 'page_label': '1'}, page_content='Journal of Hazardous Materials 416 (2021) 125928\nAvailable online 24 April 2021\n0304-3894/© 2021 The Author(s). Published by Elsevier B.V. This is an open access article under the CC BY-NC-ND license\n(http://creativecommons.org/licenses/by-nc-nd/4.0/).\nA marine bacterial community capable of degrading poly(ethylene \nterephthalate) and polyethylene \nRongrong Gao\na , b , c , d\n, Chaomin Sun\na , b , d , * \na\nCAS and Shandong Province Key Laboratory of Experimental Marine Biology & Center of Deep Sea Research, Institute of Oceanology, Chinese Academy of Sciences, \nQingdao, China \nb\nLaboratory for Marine Biology and Biotechnology, Qingdao National Laboratory for Marine Science and Technology, Qingdao, China \nc\nCollege of Earth Science, University of Chinese Academy of Sciences, Beijing, China \nd\nCenter of Ocean Mega-Science, Chinese Academy of Sciences, Qingdao, China   \nARTICLE INFO  \nEditor: Dr. Teresa A.P. Rocha-Santos  \nKeywords: \nOcean \nPlastics \nBacterial community reconstitution \nDegradation \nPollution \nABSTRACT  \nPlastic wastes are becoming the most common form of marine debris and present a growing global pollution'), Document(metadata={'producer': 'Acrobat Distiller 8.1.0 (Windows)', 'creator': 'Elsevier', 'creationdate': '2021-06-12T16:00:41+00:00', 'moddate': '2021-06-12T16:49:48+00:00', 'title': 'A marine bacterial community capable of degrading poly(ethylene terephthalate) and polyethylene', 'keywords': 'Ocean,Plastics,Bacterial community reconstitution,Degradation,Pollution', 'subject': 'Journal of Hazardous Materials, 416 (2021) 125928. doi:10.1016/j.jhazmat.2021.125928', 'author': 'Rongrong Gao', 'source': '/Users/danid/Downloads/RAG_personal_knowledge_base/new_pdfs_to_add/A marine bacterial community capable of degrading poly(ethylene terephthalate) and polyethylene.pdf', 'total_pages': 12, 'page': 0, 'page_label': '1'}, page_content='ABSTRACT  \nPlastic wastes are becoming the most common form of marine debris and present a growing global pollution \nproblem. Here, we used a screening approach on hundreds of plastic waste-associated samples and discovered a \nmarine bacterial community capable of efficiently colonizing and degrading both poly(ethylene terephthalate) \n(PET) and polyethylene (PE). Using absolute quantitative 16S rRNA sequencing and cultivation methods, we \nobtained corresponding abundance and purified cultures of three bacterial strains that mediated plastic degra -\ndation. We further performed numerous techniques to characterize the efficient degradation of PET and PE by \nthe reconstituted bacterial community containing these three bacteria. Additionally, we used liquid \nchromatography-mass spectrometry to further demonstrate the degradation of PET and PE films by the recon -\nstituted bacterial community. We conducted transcriptomic methods to investigate the plastic degradation \nprocess and potential degradation mechanisms mediated by our reconstituted bacterial community. Lastly, we \noverexpressed PE degradation enzymes based on transcriptomic results and verified their significant degradation'), Document(metadata={'producer': 'Acrobat Distiller 8.1.0 (Windows)', 'creator': 'Elsevier', 'creationdate': '2021-06-12T16:00:41+00:00', 'mo ...
#
# Database updated with new documents

# %%
# List existing documents in the vector store
docs_in_db = local_rag_sys.list_existing_documents()
docs = []
for doc in docs_in_db:
    docs.append(doc['source'])
print(set(docs))  # Display unique document titles in the vector store
# Out:
# {'/Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/Polyethylene Degradation by a Rhodococcous Strain Isolated from Naturally Weathered Plastic Waste Enrichment .pdf', '/Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx', '/Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/Biodegradation of polyethylene and polypropylene by Lysinibacillus species JJY0216 isolated from soil grove.pdf', '/Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/Selection of microorganisms capable of polyethylene (PE) and polypropylene (PP) degradation.pdf', '/Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/SaProt- Protein Language Modeling with Structure-aware Vocabulary.pdf', '/Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/Using artificial intelligence to document the hidden RNA virosphere.pdf', '/Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/Diffusion Sequence Models for Enhanced Protein Representation and Generation.pdf', '/Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/xTrimoPGLM- unified 100-billion-parameter pretrained transformer for deciphering the language of proteins.pdf', '/Users/danid/Downloads/RAG_personal_knowledge_base/new_pdfs_to_add/A marine bacterial community capable of degrading poly(ethylene terephthalate) and polyethylene.pdf'}

# %% [markdown]
# ### Single Prompts Chain (not conversation)

# %%
# Complete workflow with existing documents vector db, running QA-chain with a query to the model
# Single prompts chain
qa_chain = local_rag_sys.build_qa_chain(retriever_type="vec_semantic", 
                                        use_conversation=False)
# Out:
# No split documents available for BM25Retriever creation. Need to build vector DB first.

# %%
result = qa_chain.invoke('''How does the SaProt protein-LLM differs from other protein-LLMs such as ESM-2? 
                         Two new protein LLMs models called: Diffusion Sequence Model (DSM) and xTrimoPGLM are suppose to be state-of-the-art. Compare them to SaProt. 
                        What are the key architectural novelties of these models?
                        Use the given context (source documents) to answer the question.
                        Give the name of the source documents and metadata that supports your answer.''')

# %%
print("\n=== ANSWER ===")
print(result['result'])   
print("\n=== SOURCES ===")
for doc in result['source_documents']:
    print(f"Content: {doc.page_content[:200]}...")
    print(f"Metadata title: {doc.metadata['title']}\n")
    print(f"Metadata page number: {doc.metadata['page']}\n")
# Out:
# === ANSWER ===
# **What makes SaProt different from other protein‑LLMs**
#
# | Feature | SaProt (the “structure‑aware” LLM) | ESM‑2 (baseline LLM) |
# |---------|-----------------------------------|----------------------|
# | **Core novelty** | Introduces a *Structure‑Aware (SA) vocabulary* that concatenates the usual residue token with a structure token derived from Foldseek‑encoded 3‑D information. The model therefore sees “SA‑tokens” instead of pure amino‑acid letters. | Pure sequence‑only tokenisation; no explicit structural token. |
# | **Back‑bone** | Uses the exact same transformer architecture, size and pre‑training data as ESM‑2 (≈650 M parameters), but the input embedding layer is enlarged to accommodate the extra structure tokens. | Standard ESM‑2 transformer. |
# | **Training data** | ~40 M protein sequences *paired* with predicted structures (Foldseek/AlphaFold). This is far larger in terms of structural examples than any previous PLM. | Only raw amino‑acid sequences; no paired structures. |
# | **Resulting behaviour** | Consistently higher zero‑shot and fine‑tuned performance on 10 protein‑function tasks (Thermostability, HumanPPI, Metal‑Ion Binding, DeepLoc, etc.) and markedly better contact‑map prediction, showing that SaProt encodes more accurate structural information. | Good baseline but out‑performed by SaProt on all the same benchmarks. |
# | **Source document** | *“SAPROT: PROTEIN LANGUAGE MODELING WITH STRUCTURE‑AWARE VOCABULARY”* (Westlake University, arXiv 2025) – sections “Abstract”, “4.2.3 Results”, Table 1/2 and the discussion of the SA‑token. | Same document (comparison statements) and the background description of ESM‑2 in the same paper. |
#
# ---
#
# ### Diffusion Sequence Model (DSM)
#
# | Architectural novelties |
# |--------------------------|
# | **Diffusion‑based pre‑training** – DSM adds a *masked forward diffusion process* on top of the standard MLM objective. Tokens are progressively corrupted and then denoised, which teaches the model to reconstruct sequences even at very high mask rates (up to 90 %). |
# | **New language‑modeling head** – beyond the usual ESM‑2 token classifier, DSM introduces a diffusion head that predicts the original residues from noisy inputs. |
# | **Generative capability** – because the diffusion process is invertible, DSM can *sample* complete protein sequences in one forward pass, something pure MLM models cannot do. |
# | **Back‑bone reuse** – The underlying transformer architecture is taken directly from ESM‑2 (same layer count and hidden size), so DSM inherits the strong representation power of ESM‑2 while adding diffusion. |
# | **Performance notes** – DSM‑650 achieved the highest F1 scores among similarly sized PLMs on a broad suite of tasks, only slightly below the much larger ProtT5; it also showed a clear advantage over autoregressive (ProtCLM) and discrete‑diffusion (DPLM) baselines. |
# | **Source document** | *“Diffusion Sequence Models for Enhanced Protein Representation and Generation”* (arXiv 2025‑06‑09, authors Hallee et al.) – sections “4.4 DSM can be fine‑tuned…”, “4.3 DSM produced high‑quality embeddings…” and Table 3/Figure 4 describing the diffusion training objective. |
#
# ---
#
# ### xTrimoPGLM
#
# | Architectural novelties |
# |--------------------------|
# | **Two‑stage pre‑training** – First a massive MLM phase (≈400 B tokens) for rapid “warm‑up”, then a second phase mixing *20 % MLM* with *80 % General‑Linear‑Model (GLM)* objectives. The GLM component supplies an autoregressive generative head while retaining bidirectional context. |
# | **Scale** – 100 B parameters, trained on ≈1 trillion tokens, making it orders of magnitude larger than SaProt (650 M) or DSM (≈650 M). |
# | **Evoformer‑style modules** – The model contains *single‑representation* and *pair‑representation* streams, a recycling module (run three times), and a folding module reminiscent of AlphaFold’s Evoformer. This explicit pairwise processing is absent from SaProt/ESM‑2. |
# | **MSA‑free but multi‑modal** – Although it does not use multiple sequence alignments, the architecture can ingest residue sequences together with optional structural cues (through the pair stream) and learns to predict 3‑D geometry directly. |
# | **Benchmark superiority** – Outperforms all prior baselines on 18 protein‑understanding tasks across four categories, and attains lower perplexity on CAMEO/CASP15 than ESMFold’s PLM. |
# | **Source document** | The later part of the provided context describing *xTrimoPGLM* (sections “Evaluation of protein understanding benchmarks”, the diagram with “Input sequence → … Evoformer Structure module → Recycling module → Folding module”, and the performance summary). No separate citation line is given, but it appears in the same multi‑document dump together with the DSM paper. |
#
# ---
#
# ## Comparative Summary
#
# | Model | Core architectural idea | How it diverges from SaProt |
# |-------|------------------------|-----------------------------|
# | **SaProt** | Adds explicit structure tokens (SA‑vocab) to a standard ESM‑2 transformer. | Baseline for comparison – no diffusion, no GLM head, far smaller than xTrimoPGLM. |
# | **DSM** | Keeps the same transformer but replaces the MLM loss with a *masked diffusion* objective and adds a diffusion decoding head, enabling one‑step generative sampling. | Diffusion training vs. SaProt’s pure masked‑language‑modeling; no structure tokens (still uses ESM‑2 backbone). |
# | **xTrimoPGLM** | Massive 100 B‑parameter model with dual MLM/GLM pre‑training, Evoformer‑style single/pair streams, recycling and folding modules. | Introduces pairwise processing and a generative GLM head; scale is >150× SaProt; no explicit SA‑vocab but learns structure implicitly via the pair stream. |
#
# All three newer models aim to improve on the ESM‑2 baseline (which SaProt also improves upon) but take **different architectural routes**:
#
# * **SaProt → structural token enrichment**
# * **DSM → diffusion‑based denoising and generation**
# * **xTrimoPGLM → ultra‑large, dual‑objective, Evoformer‑inspired architecture**
#
# These differences are directly supported by the cited source documents.
#
# === SOURCES ===
# Content: • SaProt outperforms ESM-2 in all protein-level tasks. Specifically, SaProt shows remark-
# able enhancements over ESM-2 in the Thermostability, HumanPPI, Metal Ion Binding, and
# DeepLoc tasks. This outc...
# Metadata title: SaProt: Protein Language Modeling with Structure-aware Vocabulary
#
# Metadata page number: 7
#
# Content: arXiv:2506.08293v1  [q-bio.BM]  9 Jun 2025
# Diffusion Sequence Models for Enhanced Protein Representation and
# Generation
# Logan Hallee1, 2, Nikolaos Rafailidis1, David B. Bichara2, and Jason P. Gleghorn...
# Metadata title: Diffusion Sequence Models for Enhanced Protein Representation and Generation
#
# Metadata page number: 0
#
# Content: embeddings and valuable downstream tasks (datasets described in Supplemental Figure S3). DSM650 produced the highest
# quality embeddings among similarly sized pLMs, generating consistently high F1 scor...
# Metadata title: Diffusion Sequence Models for Enhanced Protein Representation and Generation
#
# Metadata page number: 6
#
# Content: ESM-2, given that residue-based PLMs also implicitly contain structure information (Rao et al.,
# 2020)? To answer it, we conduct an additional structure prediction task, namely contact map predic-
# tion...
# Metadata title: SaProt: Protein Language Modeling with Structure-aware Vocabulary
#
# Metadata page number: 7
#
# Content: tion 4.1.3. Its impressive performance positions it as a compelling alternative to the ESM family.
# 5 A NALYSIS
# We conduct insightful ablation studies by dissecting SaProt. One can find more analysis i...
# Metadata title: SaProt: Protein Language Modeling with Structure-aware Vocabulary
#
# Metadata page number: 7
#
# Content: Model ClinVar ProteinGym
# w/o MSA retrieval w/ MSA retrieval
# AUC Spearman’s ρ Spearman’s ρ
# ESM-2 (15B) 0.843 0.436 0.479
# SaProt 0.909 0.478 0.489
# Table 6: Zero-shot comparison with ESM-2 15B version. C...
# Metadata title: SaProt: Protein Language Modeling with Structure-aware Vocabulary
#
# Metadata page number: 16
#
# Content: process. DSM extends ESM2 ( 33) with a novel language modeling head and training objective, enabling robust denoising
# across high corruption rates and sequence generation with global context. After tr...
# Metadata title: Diffusion Sequence Models for Enhanced Protein Representation and Generation
#
# Metadata page number: 1
#
# Content: non-redundant version (P IDE <40%) of the SCOPe (Chandonia et al., 2018) database. For the
# alpha and beta proteins, the representations generated by ESM-2 are intertwined, whereas those gen-
# erated by...
# Metadata title: SaProt: Protein Language Modeling with Structure-aware Vocabulary
#
# Metadata page number: 8
#
# Content: Model ClinV
# ar ProteinGym(w/o MSA retrieval) DeepLoc
# Subcellular
# Binary
# A
# UC Spearman’s ρ Acc% Acc%
# Ev
# oformer-inspired ESM(35M) 0.589
# 0.178 66.11 89.25
# MIF 0.638
# 0.256 61.90 85.90
# SaProt(35M) 0.754
# 0...
# Metadata title: SaProt: Protein Language Modeling with Structure-aware Vocabulary
#
# Metadata page number: 18
#
# Content: tures. Through extensive evaluation, our SaProt model surpasses well-established
# and renowned baselines across 10 significant downstream tasks, demonstrating
# its exceptional capacity and broad applica...
# Metadata title: SaProt: Protein Language Modeling with Structure-aware Vocabulary
#
# Metadata page number: 0
#
# Content: 4.1.3 R ESULTS
# Table 1 showcases the zero-shot results on the ProteinGym and ClinVar datasets. Based on the
# results, we draw several noteworthy conclusions:
# • SaProt outperforms all residue sequence-b...
# Metadata title: SaProt: Protein Language Modeling with Structure-aware Vocabulary
#
# Metadata page number: 6
#
# Content: Interestingly, the diffusion-based pLMs showcased a distinct sequence reconstruction scaling law that became clear when
# contrasting DSM and DPLM compared to ESM2 (Figure 4). Even at 90% masking, the d...
# Metadata title: Diffusion Sequence Models for Enhanced Protein Representation and Generation
#
# Metadata page number: 6
#
# Content: ESM-2
# All alpha proteins All beta proteins
# SaProt
# All alpha proteins All beta proteins
# Figure 5: Embedding visualizations of ESM-2 and SaProt on SCOPe database.
# ACKNOWLEDGMENTS
# We thank Sergey Ovchinn...
# Metadata title: SaProt: Protein Language Modeling with Structure-aware Vocabulary
#
# Metadata page number: 9
#
# Content: SAPROT: P ROTEIN LANGUAGE MODELING WITH
# STRUCTURE -AWARE VOCABULARY
# Jin Su, Chenchen Han, Yuyang Zhou, Junjie Shan, Xibin Zhou, Fajie Yuan∗
# Westlake University
# {sujin, hanchenchen, zhouyuyang, shanjun...
# Metadata title: SaProt: Protein Language Modeling with Structure-aware Vocabulary
#
# Metadata page number: 0
#
# Content: phase. This highlights the effectiveness of SaProt, even in situations where protein structures are not
# available.
# But in general, in this specific scenario, SaProt may not exhibit a clear advantage o...
# Metadata title: SaProt: Protein Language Modeling with Structure-aware Vocabulary
#
# Metadata page number: 19
#
# Content: allows for seamless integration with advances in large-scale foundation AI models, such as
# BERT (Devlin et al., 2018), BART (Lewis et al., 2019), GPT (Brown et al., 2020), etc.
# • By utilizing the SA-t...
# Metadata title: SaProt: Protein Language Modeling with Structure-aware Vocabulary
#
# Metadata page number: 1
#
# Content: We compare SaProt with two types of baselines: sequence-based models and structure-based mod-
# els. For sequence-based models, we include ESM-1b (Rives et al., 2019), ESM-1v (Meier et al.,
# 2021) (the r...
# Metadata title: SaProt: Protein Language Modeling with Structure-aware Vocabulary
#
# Metadata page number: 5
#
# Content: Like the ESM models, SaProt aims to contribute to the advancement of the biological community.
# This study has several limitations: (1) The performance of the proposed SA vocabulary heavily
# depends on ...
# Metadata title: SaProt: Protein Language Modeling with Structure-aware Vocabulary
#
# Metadata page number: 8
#
# Content: Proteins play vital roles in the sustenance, growth and defense mecha-
# nisms of living organisms. They provide structural support for many
# essential biological processes such as synthesizing enzymes,...
# Metadata title: xTrimoPGLM: unified 100-billion-parameter pretrained transformer for deciphering the language of proteins
#
# Metadata page number: 0
#
# Content: In summary, DSM closes the gap between understanding and creating proteins in a single architecture, enabled by a few
# Python line changes, providing a foundation for rapid, scalable, and biologically ...
# Metadata title: Diffusion Sequence Models for Enhanced Protein Representation and Generation
#
# Metadata page number: 7
#
# Content: stage. Note that, the empirical studies in the Methods confirm that the
# GLM model, when continued from MLM pretraining, converges faster
# than GLM model pretrained from scratch. Thus, the initial 40...
# Metadata title: xTrimoPGLM: unified 100-billion-parameter pretrained transformer for deciphering the language of proteins
#
# Metadata page number: 4
#
# Content: 44. Xingyi Cheng, Bo Chen, Pan Li, Jing Gong, Jie Tang, and Le Song. Training compute-optimal protein language models. bioRxiv, 2024. doi: 10.1101/2024.06.06.597716.
# Pages: 2024.06.06.597716 Section: ...
# Metadata title: Diffusion Sequence Models for Enhanced Protein Representation and Generation
#
# Metadata page number: 9
#
# Content: of objectives, which has led to a strategy for training xTrimoPGLM at an
# unprecedented scale of 100 billion parameters and 1 trillion training tokens. Our
# extensive experiments reveal that (1) xTrim...
# Metadata title: xTrimoPGLM: unified 100-billion-parameter pretrained transformer for deciphering the language of proteins
#
# Metadata page number: 0
#
# Content: while CASP15 consists of 56 publicly available proteins (released in
# May 2022). Initially, we observed the perplexity (the lower the better)
# of these two datasets in PLMs, which served as the back...
# Metadata title: xTrimoPGLM: unified 100-billion-parameter pretrained transformer for deciphering the language of proteins
#
# Metadata page number: 7
#
# Content: Fig. S5. Identical mask rate comparison plot to Figure 4 except with checkpoints for DSM 650 and ESMC models added ( 45, 46). The 40k and 80k step checkpoints
# demonstrate the gradual increase in perfo...
# Metadata title: Diffusion Sequence Models for Enhanced Protein Representation and Generation
#
# Metadata page number: 16
#
# Content: In general, SaProt exhibits slightly better performance on AF2 structures, while SaProt-PDB
# achieves better accuracy on real structures. This outcome is expected as training and testing are
# consistent...
# Metadata title: SaProt: Protein Language Modeling with Structure-aware Vocabulary
#
# Metadata page number: 8
#
# Content: 85.80 74.44 0.886 0.672 0.381 0.435 84.16 93.63
# Table 2: Experimental results on 8 downstream tasks.
# 4.2.1 D ATASETS
# For protein-level tasks, we evaluate SaProt on a diverse set of datasets from sever...
# Metadata title: SaProt: Protein Language Modeling with Structure-aware Vocabulary
#
# Metadata page number: 6
#
# Content: 4.2 DSM demonstrated substantially improved sequence reconstruction compared to MLM coun-
# terparts
# In line with more direct comparisons to existing MLM-based pLMs, we examined sequence reconstruction ...
# Metadata title: Diffusion Sequence Models for Enhanced Protein Representation and Generation
#
# Metadata page number: 6
#
# Content: the return (Fig. 1b). We speculate that protein sequences, unlike natural
# language, are less smooth in semantic space and more akin to a factual
# nature. Currently, PLM-based methods still struggle t...
# Metadata title: xTrimoPGLM: unified 100-billion-parameter pretrained transformer for deciphering the language of proteins
#
# Metadata page number: 9
#
# Content: for predicting subsequent words, the prefix-encoding portion
# remains bidirectional.
# The framework of xTrimoPGLM, along with its application in down-
# stream tasks, is depicted in Fig. 1a. Motivated by...
# Metadata title: xTrimoPGLM: unified 100-billion-parameter pretrained transformer for deciphering the language of proteins
#
# Metadata page number: 1

# %%
result = qa_chain.invoke('''Which microorganisms (bacteria and fungi) are capable of degradation polyethylene (PE)?. 
                        By using which methods were they isolated and from which environments? 
                        Is Lysinibacillus and also Rhodococcous strains are capable of degrading PE? 
                        Use the given context (source documents) to answer the question.
                        Give the name of the source documents and metadata that supports your answer.''')

# %%
print("\n=== ANSWER ===")
print(result['result'])   
print("\n=== SOURCES ===")
for doc in result['source_documents']:
    print(f"Content: {doc.page_content[:200]}...")
    print(f"Metadata title: {doc.metadata['title']}\n")
    print(f"Metadata page number: {doc.metadata['page']}\n")
# Out:
# === ANSWER ===
# **Microorganisms that have been shown in the supplied documents to degrade polyethylene (PE)**
#
# | Domain | Species / genus (examples) reported as PE‑degraders | How they were obtained (isolation method & source environment) | Document(s) & bibliographic details |
# |--------|------------------------------------------------------|--------------------------------------------------------------------------|-------------------------------------|
# | **Bacteria** | • *Streptomyces* spp. ( *badius, setonia, viridosporus* )  <br>• *Bacillus* spp. (many strains cited in several surveys)  <br>• *Lysinibacillus sp.* JJY0216  <br>• *Lysinibacillus fusiformis*  <br>• *Methylobacterium paraoxydans*  <br>• *Brevibacillus borstelensis* strain 707  <br>• *Pseudomonas* spp.  <br>• *Arthrobacter* sp. (HDPE degrader)  <br>• *Priestia megaterium* (formerly *Bacillus megaterium*)  <br>• *Klebsiella pneumoniae*  <br>• *Pseudomonas fluorescens*  <br>• *Enterobacter ludwigii*  <br>• *Chryseobacterium* sp. | • **Enrichment of a mixed culture** in a minimal medium (1 % glucose + 1 % yeast extract) with pieces of LDPE/OPP; after several days the culture was plated on LB agar, single colonies were picked and identified by 16S‑rRNA sequencing. The original inoculum came from **soil collected under a kenaf–plastic composite cover** in a grove (i.e., a landfill‑type environment).  <br>• Some isolates required **pre‑treatments of the plastic** (e.g., UV irradiation for *Brevibacillus*; 65 % nitric acid for *M. paraoxydans*) before enrichment.  <br>• *Streptomyces* strains were taken from earlier literature (Pometto et al., 1992) that used **soil‑derived actinomycetes**.  <br>• *Arthrobacter* and *Pseudomonas* isolates were reported from **landfill soils** in previous studies cited in the text.  <br>• The *Rhodococcus* strain (see below) was isolated after a **609‑day enrichment of naturally weathered plastic waste** in seawater microcosms. | • “Selection of microorganisms capable of polyethylene (PE) and polypropylene (PP) degradation”, *Microbiological Research* 267 (2023).  <br>• “Biodegradation of polyethylene and polypropylene by Lysinibacillus species JJY0216 isolated from soil grove”, *Polymer Degradation and Stability* 191 (2021) 109662.  <br>• Table 1 in the same selection paper (lists *M. paraoxydans*, *B. borstelensis* etc.).  <br>• Pometto et al., 1992 (cited within the text).  <br>• Zheng et al., 2005 (cited for *Arthrobacter*). |
# | **Fungi** | • *Aspergillus* spp. (e.g., *A. niger, A. terreus*)  <br>• *Fusarium* spp. (*F. solani, F. oxysporum*)  <br>• *Penicillium* spp. (e.g., *P. simplicissimum*)  <br>• *Lecanicillium* sp.  <br>• *Trichoderma* sp.  <br>• *A. flavus*, *F. oxysporum*, *Penicillium granulatum* (reported as PP degraders but also listed among PE‑degraders in the review) | • **Direct plating of landfill/soil samples** onto agar media, followed by incubation on polyethylene granules or films; formation of a biofilm and SEM‑observed surface cracks were taken as evidence of degradation.  <br>• Some isolates came from **municipal‑landfill soils** (e.g., strains *L. araneicola*, *F. solani* mentioned in the text).  <br>• Others were obtained from **culture collections/previous studies** that had screened fungal isolates for plastic degradation (references to Koutny et al., 2006; Manzur et al., 2004; Seneviratne et al., 2006, etc.). | • Same “Selection of microorganisms…” paper (Microbiological Research 2023) – the discussion on fungal PE degraders.  <br>• The paragraph beginning “It is generally accepted that fungi degrade polyethylene more efficiently than bacteria” (cites Aspergillus, Fusarium, Penicillium).  <br>• References within that paragraph (Koutny et al., 2006; Manzur et al., 2004; Seneviratne et al., 2006) provide the original source of those isolates. |
#
# ---
#
# ### Are **Lysinibacillus** and **Rhodococcus** strains capable of degrading PE?
#
# **Yes.**
#
# * **Lysinibacillus sp.** – Both the mixed‑culture study and the pure‑culture work with strain **JJY0216** showed a **9 % weight loss of LDPE after 28 days** (pure culture) and **≈4 % loss of polypropylene** (same strain). The degradation was observed without any physicochemical pretreatment, confirming that this *Lysinibacillus* isolate can directly degrade PE.
#   *Source:* “Selection of microorganisms capable of polyethylene (PE) and polypropylene (PP) degradation”, Microbiol. Res. 267 (2023); also “Biodegradation of polyethylene and polypropylene by Lysinibacillus species JJY0216…”, Polymer Degrad. & Stability 191 (2021).
#
# * **Rhodococcus sp.** – The article **“Polyethylene Degradation by a Rhodococcous Strain Isolated from Naturally Weathered Plastic Waste Enrichment”**, *Environmental Science & Technology* 57 (2023), reports that after 30 days incubation the Rhodococcus strain A34 achieved **≈1 % weight loss of PE** together with chemical evidence (C–O, C=O groups, pits on the surface). This demonstrates that a Rhodococcus isolate can also degrade polyethylene.
#   *Source:* “Polyethylene Degradation by a Rhodococcous Strain Isolated from Naturally Weathered Plastic Waste Enrichment”, Environ. Sci. Technol. 57 (2023).
#
# ---
#
# ### Summary
#
# - A broad suite of **bacterial genera** (*Streptomyces, Bacillus, Lysinibacillus, Methylobacterium, Brevibacillus, Pseudomonas, Arthrobacter, Priestia, Klebsiella, Enterobacter, Chryseobacterium*) and **fungal genera** (*Aspergillus, Fusarium, Penicillium, Lecanicillium, Trichoderma, etc.) have been documented in the supplied texts as being able to break down polyethylene.
# - The isolates were obtained mainly by **enrichment culturing of soil or landfill material** (including a kenaf‑plastic composite site) in minimal media containing PE as the sole carbon source, sometimes after **pre‑treatment of the polymer**, followed by plating and molecular identification (16S rRNA for bacteria; ITS/ morphological ID for fungi). Additional isolates came from **long‑term natural weathering enrichments** (Rhodococcus) or from previously published collections.
# - Both **Lysinibacillus sp. JJY0216** and a **Rhodococcus sp. strain A34** are explicitly shown in the provided documents to degrade PE, confirming their capability.
#
# === SOURCES ===
# Content: and domestic applications. Polyethylene and polypropylene account for more than 50% of total plastic
# usage, and they resist decomposition in a natural environment. In this study, Lysinibacillus sp., ...
# Metadata title: Biodegradation of polyethylene and polypropylene by Lysinibacillus species JJY0216 isolated from soil grove
#
# Metadata page number: 0
#
# Content: than the number of bacterial strains. It is generally accepted that fungi
# degrade polyethylene more efficiently than bacteria ( Muhonja et al.,
# 2018 ). The first reason for this difference is the ab...
# Metadata title: Selection of microorganisms capable of polyethylene (PE) and polypropylene (PP) degradation
#
# Metadata page number: 6
#
# Content: the degradation process ( Orr et al., 2004 ). Structural changes were also
# analyzed using SEM.
# Based on the literature, biodegradation of polyethylene by micro -
# organisms was investigated as early ...
# Metadata title: Selection of microorganisms capable of polyethylene (PE) and polypropylene (PP) degradation
#
# Metadata page number: 6
#
# Content: dation experiments. A minimal medium, with continuous feeding
# with glucose and yeast extract, was used to examine degradation.
# The growth of the mixed culture reached a stationary phase in four
# day...
# Metadata title: Biodegradation of polyethylene and polypropylene by Lysinibacillus species JJY0216 isolated from soil grove
#
# Metadata page number: 2
#
# Content: the tested polymer ( Restrepo-Fl ´orez et al., 2014 ) but does not apply to
# the P. megaterium (former Bacillus megaterium ) strain that was isolated
# from soil samples taken at a landfill. S. marcesc...
# Metadata title: Selection of microorganisms capable of polyethylene (PE) and polypropylene (PP) degradation
#
# Metadata page number: 6
#
# Content: Microbiological Research 267 (2023) 127251
# Available online 8 November 2022
# 0944-5013/© 2022 Published by Elsevier GmbH. This article is made available under the Elsevier license (http://www.elsevier....
# Metadata title: Selection of microorganisms capable of polyethylene (PE) and polypropylene (PP) degradation
#
# Metadata page number: 0
#
# Content: Polymer Degradation and Stability 191 (2021) 109662
# Contents lists available at ScienceDirect
# Polymer Degradation and Stability
# journal homepage: www.elsevier.com/locate/polymdegradstab
# Biodegrada...
# Metadata title: Biodegradation of polyethylene and polypropylene by Lysinibacillus species JJY0216 isolated from soil grove
#
# Metadata page number: 0
#
# Content: In conclusion, the isolation of plastic-degrading bacteria and fungi from waste landfills represents an effective
# strategy for the collection of microorganisms with high potential for PE and PP degra...
# Metadata title: Selection of microorganisms capable of polyethylene (PE) and polypropylene (PP) degradation
#
# Metadata page number: 0
#
# Content: Polyethylene Degradation by a Rhodococcous Strain Isolated from
# Naturally Weathered Plastic Waste Enrichment
# Xuanyu Tao, Huanrong Ouyang, Aifen Zhou,* Dongyu Wang, Hagan Matlock, Josiah S. Morgan,
# Abi...
# Metadata title: Polyethylene Degradation by a Rhodococcous Strain Isolated from Naturally Weathered Plastic Waste Enrichment
#
# Metadata page number: 0
#
# Content: Biodeterior. Biodegradation 113 (2016) 244–255 .
# [14] S. Mukherjee , U.R. Chowdhuri , P.P. Kundu , Bio-degradation of polyethylene
# waste by simultaneous use of two bacteria: bacillus licheniformis f...
# Metadata title: Biodegradation of polyethylene and polypropylene by Lysinibacillus species JJY0216 isolated from soil grove
#
# Metadata page number: 7
#
# Content: biodegradation of polymers.
# We assumed that natural biological material collected from a landfill
# will contain some microorganisms capable of utilizing polymers (PE and
# PP) as the primary source of...
# Metadata title: Selection of microorganisms capable of polyethylene (PE) and polypropylene (PP) degradation
#
# Metadata page number: 1
#
# Content: UV light before inoculation with Bacillus flexus and reveald 2.5 %
# reduction in polymer weight, compared to non-inoculated control
# variant. It was confirmed that PE known for its high density (HDPE)...
# Metadata title: Selection of microorganisms capable of polyethylene (PE) and polypropylene (PP) degradation
#
# Metadata page number: 1
#
# Content: J.-M. Jeon, S.-J. Park, T.-R. Choi et al. Polymer Degradation and Stability 191 (2021) 109662
# dation in natural environments. Several microbial species, includ-
# ing Bacillus sp., Brevibacillus borst...
# Metadata title: Biodegradation of polyethylene and polypropylene by Lysinibacillus species JJY0216 isolated from soil grove
#
# Metadata page number: 1
#
# Content: J.-M. Jeon, S.-J. Park, T.-R. Choi et al. Polymer Degradation and Stability 191 (2021) 109662
# Fig. 5. Scheme of biological degradation process for plastic waste.
# study can be used as a basis for fur...
# Metadata title: Biodegradation of polyethylene and polypropylene by Lysinibacillus species JJY0216 isolated from soil grove
#
# Metadata page number: 6
#
# Content: J.-M. Jeon, S.-J. Park, T.-R. Choi et al. Polymer Degradation and Stability 191 (2021) 109662
# Fig. 3. Biodegradation ability of polyethylene and polypropylene by Lysinibacillus sp. JJY0216. Growth of...
# Metadata title: Biodegradation of polyethylene and polypropylene by Lysinibacillus species JJY0216 isolated from soil grove
#
# Metadata page number: 3
#
# Content: pounds, which are secreted and broken down by the last group of
# microbes ( Shah et al., 2008 ). It is worth noting that the efficiency of
# microorganisms ’ degradation capacity varies under different...
# Metadata title: Selection of microorganisms capable of polyethylene (PE) and polypropylene (PP) degradation
#
# Metadata page number: 1
#
# Content: degradation of plastic waste. Notably, the three bacteria within our
# reconstituted bacterial community (Exiguobacterium sp., Halomonas sp.
# and Ochrobactrum sp.) are all fast growing and easily cultu...
# Metadata title: A marine bacterial community capable of degrading poly(ethylene terephthalate) and polyethylene
#
# Metadata page number: 10
#
# Content: J.-M. Jeon, S.-J. Park, T.-R. Choi et al. Polymer Degradation and Stability 191 (2021) 109662
# Fig. 1. Biodegradation of polyethylene and polypropylene by mixed culture. Growth of mixed culture and we...
# Metadata title: Biodegradation of polyethylene and polypropylene by Lysinibacillus species JJY0216 isolated from soil grove
#
# Metadata page number: 2
#
# Content: ture of polypropylene.
# Moreover, the crystallinity of each LDPE and OPP was calcu-
# lated. Compared with the 46% crystallinity of control LDPE, LDPE
# biodegraded by Lysinibacillus sp. JJY0216 and mix...
# Metadata title: Biodegradation of polyethylene and polypropylene by Lysinibacillus species JJY0216 isolated from soil grove
#
# Metadata page number: 4
#
# Content: ( Benedict et al., 1983 ); however, its pathogenic nature means that it
# cannot be viewed as a potential agent used in applied research.
# 5. Conclusion
# Incubation of biological materials extracted fr...
# Metadata title: Selection of microorganisms capable of polyethylene (PE) and polypropylene (PP) degradation
#
# Metadata page number: 9
#
# Content: stabilization. Macromol. Symp. 115, 143 – 163. https://doi.org/10.1002/
# masy.19971150110 .
# Pramila, R., Ramesh, K., 2017. Biodegradation of low density polyethylene (LDPE) by
# fungi isolated from mu...
# Metadata title: Selection of microorganisms capable of polyethylene (PE) and polypropylene (PP) degradation
#
# Metadata page number: 10
#
# Content: proximately 7.5% on day 28 ( Fig. 3 B). The OPP ﬁlm’s weight was
# decreased by approximately 3.1% on day 28, a result consistent
# with the mixed culture ﬁndings ( Fig. 3 B). These results are more
# th...
# Metadata title: Biodegradation of polyethylene and polypropylene by Lysinibacillus species JJY0216 isolated from soil grove
#
# Metadata page number: 2
#
# Content: microorganism-mediated PE degradation lags well behind. Further -
# more, degradation efficiencies for single strains or single enzymes are
# still too low to meet industrial application requirements. Al...
# Metadata title: A marine bacterial community capable of degrading poly(ethylene terephthalate) and polyethylene
#
# Metadata page number: 1
#
# Content: shown that microorganisms, including bacteria and fungi as
# well as insects and the associated gut microorganisms, can
# degrade various types of plastics such as polyethylene (PE),
# polystyrene (PS), pol...
# Metadata title: Polyethylene Degradation by a Rhodococcous Strain Isolated from Naturally Weathered Plastic Waste Enrichment
#
# Metadata page number: 0
#
# Content: ethylene (PE) and polypropylene (PP) degradation and assessed the scale of polymer degradation by microbial
# populations.
# We isolated seven bacterial strains (three Priestia megaterium strains, Klebs...
# Metadata title: Selection of microorganisms capable of polyethylene (PE) and polypropylene (PP) degradation
#
# Metadata page number: 0
#
# Content: chloride coating under the effect of microorganisms. Prot. Met. 23, 173 – 175 .
# Mohanan, N., Montazer, Z., Sharma, P.K., Levin, D.B., 2020. Microbial and enzymatic
# degradation of synthetic plastics....
# Metadata title: Selection of microorganisms capable of polyethylene (PE) and polypropylene (PP) degradation
#
# Metadata page number: 10
#
# Content: and PE degradation by this reconstituted bacterial community. Lastly,
# we used transcriptomic methods to clarify the potential degradation
# processes and enzymes associated with these processes.
# 2. M...
# Metadata title: A marine bacterial community capable of degrading poly(ethylene terephthalate) and polyethylene
#
# Metadata page number: 1
#
# Content: ing in rarely biodegradable in the absence of pretreatment pro-
# cesses such as extended time exposure to high temperature or
# UV exposure [1] . These C –C chains can be broken by alkane de-
# hydrogen...
# Metadata title: Biodegradation of polyethylene and polypropylene by Lysinibacillus species JJY0216 isolated from soil grove
#
# Metadata page number: 1
#
# Content: Microbiological Research 267 (2023) 127251
# 10
# Aspergillus niger, A. terreus, Aureobasidium pullulans, Chaetomium
# globosum, Paecilomyces variotii, and Scopulariopsis brevicaulis are fungal
# strains th...
# Metadata title: Selection of microorganisms capable of polyethylene (PE) and polypropylene (PP) degradation
#
# Metadata page number: 9
#
# Content: tured at 30 ◦C by inoculating 0.1 g of soil sample with 50 mL
# of Luria–Bertani (LB) medium. The same conditions were used for
# seed culture to assess biodegradability. To isolate a single strain
# fro...
# Metadata title: Biodegradation of polyethylene and polypropylene by Lysinibacillus species JJY0216 isolated from soil grove
#
# Metadata page number: 1

# %%
result = qa_chain.invoke('''Summarize the main group of TNT degrading microbial species, separate into Aerobic vs. Anaerobic bacteria, what are the main differences? 
                        Use the given context (source documents) to answer the question.
                        Give the name of the source documents and metadata that supports your answer.''')

# %%
print("\n=== ANSWER ===")
print(result['result'])   
print("\n=== SOURCES ===")
for doc in result['source_documents']:
    print(f"Content: {doc.page_content[:200]}...")
    print(f"Metadata title: {doc.metadata['source']}\n")
# Out:
# === ANSWER ===
# **Main groups of TNT‑degrading microbes (as described in the document “Comprehensive analysis of microbial TNT degradation”)**
#
# |                     | Representative taxa mentioned in the text | Typical metabolic features |
# |---------------------|-------------------------------------------|----------------------------|
# | **Aerobic bacteria** | • *Pseudomonas* spp. (e.g., *P. fluorescens*, *P. putida*)  <br>• *Bacillus* spp.<br>• *Staphylococcus* spp.<br>• *Mycobacterium* spp.<br>• *Rhodococcus* spp. (e.g., *R. erythropolis*)<br>• *Serratia marcescens* <br>• *Stenotrophomonas* isolates | – Operate in the presence of O₂.  <br>– Initiate TNT degradation by **nitro‑group reduction** (nitroreductases, azoreductases) producing hydroxylamino‑ and amino‑dinitrotoluenes (ADNTs, DANTs).<br>– Some strains form Meisenheimer σ‑complexes that release nitrite (denitration) and generate dinitrotoluene intermediates that can be further attacked by dioxygenases.<br>– Frequently generate **azoxy dimers** or polymeric products; complete mineralisation of the aromatic ring is rare.  <br>– Often use TNT only as a nitrogen source, not for growth energy. |
# | **Anaerobic bacteria** | • *Veillonella alkalescens*<br>• *Escherichia coli* (facultative)<br>• *Clostridium* spp. (*C. bifermentans*, *C. acetobutylicum*, *C. pasterianum*, *C. sordellii*)<br>• *Desulfovibrio* spp.<br>• Methanogenic archaea (e.g., *Methanococcus*) | – Function when O₂ is absent or limited.  <br>– Carry out **sequential six‑electron reductions** of each nitro group, converting TNT → TAT (2,4,6‑triaminotoluene). <br>– Reduction proceeds through nitroso → hydroxylamino → amine intermediates; often mediated by oxygen‑insensitive nitroreductases. <br>– The fully reduced product (TAT) is chemically unstable and tends to polymerise or adsorb, but the pathway removes all nitro groups – a step that aerobic cells rarely achieve.  <br>– Some anaerobes can use TNT as an **electron acceptor** (e.g., *Desulfovibrio* spp.) or as a nitrogen source; the process does not generate much energy for growth but alleviates toxicity. |
#
# ### Main differences between aerobic and anaerobic TNT‑degrading bacteria
#
# | Aspect | Aerobic bacteria | Anaerobic bacteria |
# |-------|------------------|--------------------|
# | **Electron acceptor** | O₂ is available; oxygenases can act after nitro‑group reduction. | No O₂; reduction relies on electron donors such as H₂, NADH, or ferredoxin. |
# | **Extent of nitro‑group removal** | Typically removes one or two nitro groups (ADNTs/DANTs); complete three‑step reduction to TAT is uncommon. | Generally reduces **all three** nitro groups → TAT; the pathway can be “complete” with respect to denitration. |
# | **Aromatic ring fate** | Ring often remains intact; further oxidation to catechol or mineralisation occurs only after conversion to dinitrotoluene (e.g., via Meisenheimer complex). | The aromatic ring may stay intact as TAT, which can polymerise or be immobilised; true mineralisation of the carbon skeleton is still rare. |
# | **Typical products** | ADNTs, DANTs, azoxy dimers, nitrite, occasional dinitrotoluene that enters known dioxygenase pathways. | TAT (2,4,6‑triaminotoluene), sometimes aminophenols or toluene (via speculative deamination). |
# | **Physiological role** | Often use TNT as a nitrogen source; the process is largely co‑metabolic and can be coupled to growth on other carbon sources. | TNT may serve as an electron sink/terminal electron acceptor or as a nitrogen source; reduction does not provide substantial energy but reduces toxicity. |
# | **Representative environments** | Oxic soils, composts, aerobic bioreactors. | Anoxic sediments, flooded soils, anaerobic digesters, sulfate‑reducing zones. |
#
# ### Source documents & metadata supporting the answer
#
# 1. **Section “TNT‑Degrading Microbial Species – Aerobic Bacteria”** (within the main document).
#    *Mentions*: *Pseudomonas spp.*, *Bacillus*, *Staphylococcus*, *Mycobacterium*, *Rhodococcus erythropolis*, *Serratia marcescens*, *Stenotrophomonas* – describes aerobic nitro‑group reduction, Meisenheimer complexes and limited mineralisation.
#
# 2. **Section “Other Anaerobes”** (within the same document).
#    *Mentions*: *Veillonella alkalescens*, *Escherichia coli* (facultative), methanogenic archaea (*Methanococcus*) – outlines anaerobic complete reduction to TAT.
#
# 3. **Section “Clostridium spp.”** under “Multi‑Omics Approaches and Systems Biology Insights”.
#    *Details*: *Clostridium bifermentans*, *C. acetobutylicum*, etc., converting TNT → DANTs → TAT; notes Bamberger rearrangement, azoxy polymer formation.
#
# 4. **Section “Anaerobic Bacteria”** and **“Complete Reduction (Anaerobic Pathway)”** subsections.
#    *Describes*: sequential six‑electron reductions, role of sulfate‑reducers (*Desulfovibrio* spp.), use of TNT as electron acceptor.
#
# 5. **Reference list entries** that give bibliographic metadata:
#
#    - Ramos, J.L., et al. (2001). *Biological degradation of 2,4,6‑trinitrotoluene (TNT)*. **Microbiology and Molecular Biology Reviews**, 65(3):335–352. *(Provides background on TNT biodegradation.)*
#    - Cabrera, M.Á., Márquez, S.L., & Pérez‑Donoso, J.M. (2022). *Comparative genomic analysis of Antarctic Pseudomonas isolates with 2,4,6‑trinitrotoluene transformation capabilities*. **Microorganisms**, 10(8):1581. *(Supports aerobic Pseudomonas data.)*
#    - Ziganshin, A.M., et al. (2007). *Hydride‑mediated reduction of 2,4,6‑trinitrotoluene by yeasts as a way to its deep degradation*. **Mikrobiologiia**, 76(6):766–773. *(Although about yeasts, it reinforces the contrast between aerobic nitro‑reduction and deeper anaerobic‐type reductions.)*
#
# These sections collectively provide the taxonomy of aerobic vs. anaerobic TNT‑degrading bacteria and the mechanistic differences highlighted above.
#
# === SOURCES ===
# Content: Scope of Document: This document provides a comprehensive analysis of microbial TNT degradation. We first catalog the known TNT-degrading species across bacteria, fungi, and yeasts, highlighting their...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: Aerobic Bacteria: Under oxic conditions, many soil bacteria can initiate TNT degradation by partial reduction of its nitro groups or removal of nitrite. Notable examples include:
#
# • Pseudomonas spp.: ...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Other Anaerobes: Veillonella alkalescens was one of the first organisms noted to reduce TNT to TAT under strictly anaerobic conditions. Even Escherichia coli (facultative anaerobe) can perform compl...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: Microbial Bioremediation: The use of microorganisms to detoxify and remove TNT from the environment offers a promising alternative to costly physicochemical cleanup methods . Certain bacteria and fung...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: In summary, TNT degradation pathways are complex and can follow multiple routes depending on the organism and conditions. Aerobic processes excel at initial transformations and co-metabolic turnover o...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Clostridium spp.: These obligate anaerobes are among the most effective TNT degraders in anoxic conditions. Clostridium bifermentans strains transform TNT through successive reductions to diaminonit...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Other Aerobes: Bacillus and Staphylococcus species can reduce TNT, typically to monoamino dinitrotoluene (e.g., 2-amino-4,6-dinitrotoluene) with nitrite release. Mycobacterium and Rhodococcus (Gram-...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: Comparative Genomic Insights: Genome sequencing of TNT-degrading strains has shed light on their evolutionary adaptations. For example, three Antarctic Pseudomonas isolates (TNT3, TNT11, TNT19) were s...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: Complete Reduction (Anaerobic Pathway): In oxygen-free environments, TNT can be fully reduced to TAT (2,4,6-triaminotoluene) by certain bacteria. This occurs via sequential addition of six electrons (...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: with other anaerobic processes (e.g., use of TNT as a terminal electron acceptor). In remediation strategies, an anaerobic phase is sometimes used to reduce TNT to TAT, followed by an aerobic phase to...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: . These azoxy compounds are intensely colored, highly recalcitrant, and represent dead-end immobilization products in many TNT-fed cultures . In summary, aerobic nitro-reduction rapidly eliminates TNT...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: Anaerobic Degradation Routes: In oxygen-free environments, TNT undergoes more complete reduction. The hallmark of anaerobic TNT metabolism is the production of triaminotoluene (TAT). This results from...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Sulfate-Reducers: Desulfovibrio species can anaerobically respire TNT. For example, Desulfovibrio sp. strain B uses TNT as a nitrogen source and may produce toluene as a downstream product . Other D...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: In summary, the genetic toolkit for TNT biodegradation comprises mostly reductive enzymes that either remove nitro groups or destabilize the aromatic ring, along with supporting systems to manage stre...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: Genomic and Metabolic Insights into Microbial Biodegradation of TNT
#
#
#
# Abstract...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: on TNT as sole nitrogen source and was suggested to sequentially remove all three nitro substituents, as evidenced by detection of DNTs, mononitrotoluene, and toluene in culture . The release of nitri...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: In summary, omics studies have expanded our understanding from individual enzymes to the global response of microorganisms to TNT. They reveal that TNT degradation is an orchestrated event involving s...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: Genomic Insights: Key Genes and Enzymes
#
#
#
# Microbial TNT degradation relies on a suite of specialized enzymes that initiate TNT transformation despite its inert aromatic structure. Genomic and biochem...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: to its electron transport chain, certain metabolic pathways, and motility functions during TNT exposure. This likely reflects a shift to a slower-growing, stress-resistant state: the bacterium conserv...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Nitroreductases (Type I): A common entry point for TNT metabolism is the stepwise reduction of nitro (-NO₂) groups to nitroso (-NO), hydroxylamino (-NHOH), and amino (-NH₂) groups. These reactions a...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Azoreductases: An unexpected finding from genomic studies is the involvement of azoreductase enzymes in TNT degradation. Azoreductases normally reduce azo bonds (–N=N–) in dyes, but some can also re...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: 7. Hannink, N.K., et al. (2001). Phytodetoxification of TNT by transgenic plants expressing a bacterial nitroreductase. Nature Biotechnology, 19(12): 1168–1172 .
#
# 8. Duque, E., et al. (1993). Identifi...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: Key Intermediates and Fate: Across these pathways, the recurring intermediates are: hydroxylamino-dinitrotoluenes, amino-dinitrotoluenes (ADNTs), diaminonitrotoluenes (DANTs), and triaminotoluene (TAT...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Transcriptomic Profiling: Genome-wide RNA expression analyses reveal which genes are turned on or off in the presence of TNT. A recent study examined the transcriptome of Pseudomonas sp. TNT3 (an An...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Enterobacteriaceae: Enterobacter cloacae PB2 is capable of denitrating TNT. It reduces TNT via formation of a Meisenheimer complex and releases nitrite . An NADPH-dependent enzyme called pentaerythr...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Accessory and Regulatory Genes: Alongside catabolic enzymes, microbes possess regulatory and support genes that enable TNT degradation. These include: (1) oxidative stress response genes – TNT redox...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Candida and Geotrichum: Environmental yeast isolates Candida sp. AN-L15 and Geotrichum sp. AN-Z4 degrade TNT through an alternative pathway dominated by hydride attack on the aromatic ring . These y...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: Aerobic Degradation Routes: In the presence of oxygen, TNT is not readily mineralized, but it undergoes a series of reductive transformations: the dominant pathway is sequential nitro-group reduction....
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: 2. Cabrera, M.Á., Márquez, S.L., & Pérez-Donoso, J.M. (2022). Comparative genomic analysis of Antarctic Pseudomonas isolates with 2,4,6-trinitrotoluene transformation capabilities reveals their unique...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Yarrowia lipolytica: This robust yeast is known for degrading hydrocarbons and was also reported to degrade TNT. Studies found that factors like pH influence TNT transformation by Y. lipolytica, and...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx

# %%
result = qa_chain.invoke('''What are the main genes and enzymes involved in TNT degradation? 
                        Make a brief summary of the mechanism of action of each such gene/enzyme.
                        Use the given context (source documents) to answer the question.
                        Give the name of the source documents and metadata that supports your answer.''')

# %%
print("\n=== ANSWER ===")
print(result['result'])   
print("\n=== SOURCES ===")
for doc in result['source_documents']:
    print(f"Content: {doc.page_content[:200]}...")
    print(f"Metadata title: {doc.metadata['source']}\n")
# Out:
# === ANSWER ===
# **Main genes / enzymes that have been identified in the microbial degradation of 2‑4‑6‑trinitrotoluene (TNT)**
#
# | Gene / Enzyme (example) | Primary catalytic/mechanistic role in TNT turnover | Where this information appears in the supplied context |
# |--------------------------|---------------------------------------------------|--------------------------------------------------------|
# | **Type I nitroreductases** – *nfsA, nfsB, nemA* (e.g., NemA from a Citrobacter sp.) | Two‑electron reduction of TNT’s nitro groups (–NO₂ → –NO → –NHOH → –NH₂) using FMN/FAD and NAD(P)H as electron donors. This generates aminodinitrotoluene (ADNT) intermediates but does **not** cleave the aromatic ring. | “Nitroreductases (Type I)… genes encoding such enzymes (e.g., nfsA, nfsB … nemA…) have been found… NemA was most up‑regulated… converts TNT to 4‑ADNT and 2‑ADNT.” – *Genomic Insights: Key Genes and Enzymes*; also in the “TNT‑Degrading Microbial Species” section. |
# | **Azoreductase** (azoreductase‑encoding gene highly induced in *Pseudomonas sp.* TNT3) | Reduces nitro‑aromatic or hydroxylamino intermediates that arise during TNT catabolism; may attack TNT itself or its hydroxylamine derivatives, helping to prevent accumulation of toxic intermediates. The enzyme is an FMN‑dependent reductase that uses NAD(P)H. | “Azoreductases… a recent transcriptomic analysis … revealed an azoreductase‑encoding gene as the most highly induced gene (>1000‑fold…) during TNT exposure.” – *Genomic Insights: Key Genes and Enzymes*; also reiterated in “Transcriptomic Profiling”. |
# | **Old Yellow Enzyme (OYE) family flavoprotein reductases** – e.g., PETN reductase (*petnR / pnrA*), XenA/B, NEM reductases | Catalyze hydride transfer from NADPH to the electron‑poor aromatic ring of TNT, forming a σ‑Meisenheimer complex that spontaneously eliminates nitrite (denitration). This both reduces nitro groups and destabilises the ring, opening pathways toward ring cleavage. | “Old Yellow Enzyme … enzymes … include PETN reductase (gene petnR, also known as pnrA)… can perform hydride ion attack on the aromatic ring of TNT, yielding a σ‑complex that spontaneously eliminates nitrite.” – *Genomic Insights: Key Genes and Enzymes*; further discussed under “Old Yellow Enzyme (OYE) Family & Flavoprotein Reductases”. |
# | **NADPH dehydrogenase NamA** | Supplies reducing power (NADPH) to the above reductases, thereby supporting the two‑electron reductions of nitro groups and Meisenheimer‑complex formation. | “NADPH dehydrogenase NamA” is listed under *Extra material: additional genes/pathways related to TNT‑biodegradation*. |
# | **Oxidative‑stress enzymes** – Superoxide dismutases (SOD), peroxidases, catalases | Scavenge reactive oxygen species generated by TNT redox cycling; protect cellular macromolecules while the reductive catabolism proceeds. | “Accessory and Regulatory Genes… oxidative stress response genes – … superoxide dismutases and peroxidases are often up‑regulated” – *Genomic Insights: Key Genes and Enzymes*. |
# | **Nitrosative‑stress enzymes** – Nitric‑oxide dioxygenase, DNA‑repair proteins | Detoxify nitric oxide / nitroso intermediates that arise from nitro‑group reduction; repair damage to nucleic acids. | Same paragraph as above (oxidative‑stress genes). |
# | **Assimilatory nitrite reductase (NasB) & related nitrogen‑assimilation enzymes** (e.g., glutamine synthetase) | Reduce nitrite released during denitration to ammonium and incorporate it into amino‑acid biosynthesis, allowing the cell to use TNT as a nitrogen source. | “Nitrite Reductases and Assimilatory Enzymes… NasB … together convert TNT‑derived nitrite into ammonium for incorporation” – *Introduction* section. |
# | **Multidrug efflux pumps / transporters** (e.g., RND family) | Export TNT, its reduced products or toxic intermediates out of the cytoplasm, lowering intracellular concentrations and alleviating stress. | “Transporters and efflux pumps… multidrug efflux systems … likely to reduce intracellular toxin accumulation” – *Genomic Insights: Key Genes and Enzymes*. |
# | **Regulatory proteins** – LysR‑type, MarR‑type transcriptional regulators (often plasmid‑borne) | Sense TNT or its metabolites and activate expression of the catabolic operons (nitroreductases, azoreductase, efflux pumps). | “Regulators … specialized regulators (e.g., LysR‑type or MarR‑type regulators) may sense TNT… Some TNT‑degrading plasmids carry such regulatory genes” – *Genomic Insights: Key Genes and Enzymes*. |
#
# ---
#
# ### How each component fits into the overall degradation mechanism
#
# 1. **Initial reduction of nitro groups** – Type I nitroreductases (e.g., NemA) perform sequential two‑electron reductions, converting TNT → 4‑ADNT/2‑ADNT → amino‑dinitrotoluenes.
# 2. **Alternative / complementary reduction** – Azoreductase and OYE‑family enzymes act in parallel: the azoreductase can reduce hydroxylamine intermediates; OYE enzymes (PETN reductase, XenA/B) add a hydride to the aromatic ring forming a Meisenheimer σ‑complex that ejects nitrite, yielding dinitrotoluene (DNT) or other de‑nitro products.
# 3. **Support of redox balance** – NADPH‑generating enzymes such as NamA keep the reductases supplied with reducing equivalents.
# 4. **Stress mitigation** – Superoxide dismutase, peroxidases, nitric‑oxide detoxifiers, and DNA‑repair proteins protect the cell from ROS/RNS generated during TNT reduction.
# 5. **Nitrogen assimilation** – NasB reduces released nitrite to ammonia; downstream ammonium‑assimilating enzymes incorporate this nitrogen into biomass.
# 6. **Detoxification & export** – Multidrug efflux pumps pump out residual TNT or toxic intermediates, reducing intracellular toxicity.
# 7. **Regulation** – LysR/MarR‐type regulators (often on the same plasmid as catabolic genes) sense TNT or its reduced metabolites and up‑regulate the whole suite of degradation genes only when needed.
#
# ---
#
# ### Source documents & metadata used
#
# | Document / Section | Type / Year (where provided) |
# |--------------------|------------------------------|
# | **Genomic Insights: Key Genes and Enzymes** – multiple paragraphs on nitroreductases, azoreductase, OYE family, stress genes, transporters, regulators. | Unspecified report (part of the supplied “Genomic Insights” chapter). |
# | **Transcriptomic Profiling** – description of >1000‑fold azoreductase induction in *Pseudomonas sp.* TNT3. | Same source as above; internal heading. |
# | **TNT‑Degrading Microbial Species** – discussion of nitroreductases (nemA, nfsA/B) and their role. | Same overarching document. |
# | **Old Yellow Enzyme (OYE) Family & Flavoprotein Reductases** – details on PETN reductase, XenA/B, Meisenheimer complex formation. | Same source; internal heading. |
# | **Introduction** (section “Nitrite Reductases and Assimilatory Enzymes”). | Same source. |
# | **Extra material: additional genes/pathways related to TNT‑biodegradation** – mention of NADPH dehydrogenase NamA. | Same source. |
# | **References cited in the text** (e.g., Cabrera et al. 2024; Liao et al. 2018) – provide bibliographic metadata for specific studies that reported azoreductase induction, nitroreductase up‑regulation, etc. | Author(s), year as shown in reference list. |
#
# All the above points are drawn **exclusively** from the supplied context; no external knowledge was introduced.
#
# === SOURCES ===
# Content: Genomic Insights: Key Genes and Enzymes
#
#
#
# Microbial TNT degradation relies on a suite of specialized enzymes that initiate TNT transformation despite its inert aromatic structure. Genomic and biochem...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Functional Genomics: Another omics-related approach is random mutagenesis or knockout studies combined with sequencing to find genes essential for TNT metabolism. Transposon mutagenesis, for instanc...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Accessory and Regulatory Genes: Alongside catabolic enzymes, microbes possess regulatory and support genes that enable TNT degradation. These include: (1) oxidative stress response genes – TNT redox...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Azoreductases: An unexpected finding from genomic studies is the involvement of azoreductase enzymes in TNT degradation. Azoreductases normally reduce azo bonds (–N=N–) in dyes, but some can also re...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Systems Biology and Modeling: With large omics datasets, scientists have begun constructing regulatory and metabolic network models for TNT-degrading organisms. For instance, integrating the transcr...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Transcriptomic Profiling: Genome-wide RNA expression analyses reveal which genes are turned on or off in the presence of TNT. A recent study examined the transcriptome of Pseudomonas sp. TNT3 (an An...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: In summary, the genetic toolkit for TNT biodegradation comprises mostly reductive enzymes that either remove nitro groups or destabilize the aromatic ring, along with supporting systems to manage stre...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: Comparative Genomic Insights: Genome sequencing of TNT-degrading strains has shed light on their evolutionary adaptations. For example, three Antarctic Pseudomonas isolates (TNT3, TNT11, TNT19) were s...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: Scope of Document: This document provides a comprehensive analysis of microbial TNT degradation. We first catalog the known TNT-degrading species across bacteria, fungi, and yeasts, highlighting their...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Metabolomics and Pathway Confirmation: While less reported than transcript/proteome data, metabolomic analyses (identifying intermediate compounds) and isotope tracing have been used to confirm TNT ...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Nitroreductases (Type I): A common entry point for TNT metabolism is the stepwise reduction of nitro (-NO₂) groups to nitroso (-NO), hydroxylamino (-NHOH), and amino (-NH₂) groups. These reactions a...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: In summary, omics studies have expanded our understanding from individual enzymes to the global response of microorganisms to TNT. They reveal that TNT degradation is an orchestrated event involving s...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Proteomic Analyses: Complementing transcriptomics, proteomics examines changes in the protein complement of a cell in response to TNT. In one study, researchers performed an integrated proteome and ...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: Genomic and Metabolic Insights into Microbial Biodegradation of TNT
#
#
#
# Abstract...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: to its electron transport chain, certain metabolic pathways, and motility functions during TNT exposure. This likely reflects a shift to a slower-growing, stress-resistant state: the bacterium conserv...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: 7. Hannink, N.K., et al. (2001). Phytodetoxification of TNT by transgenic plants expressing a bacterial nitroreductase. Nature Biotechnology, 19(12): 1168–1172 .
#
# 8. Duque, E., et al. (1993). Identifi...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: Microbial Bioremediation: The use of microorganisms to detoxify and remove TNT from the environment offers a promising alternative to costly physicochemical cleanup methods . Certain bacteria and fung...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: In summary, TNT degradation pathways are complex and can follow multiple routes depending on the organism and conditions. Aerobic processes excel at initial transformations and co-metabolic turnover o...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Dioxygenases and Ring-Cleavage Enzymes: Direct oxidative ring cleavage of TNT is very challenging due to its electron-poor ring, and no dedicated TNT dioxygenase has been identified. However, once T...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: Abstract
#
# 2,4,6-Trinitrotoluene (TNT) is a recalcitrant explosive pollutant whose breakdown in the environment is facilitated by diverse microbes. This document summarizes key findings on TNT biodegra...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Nitrite Reductases and Assimilatory Enzymes: Though not directly modifying TNT, enzymes like assimilatory nitrite reductase (NasB) and ammonium-assimilating enzymes (e.g., glutamine synthetase) are ...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: Monooxygenases and Dioxygenases: Enzymes that incorporate oxygen into aromatic rings (like ring-hydroxylating dioxygenases or monooxygenases) are central to degrading simpler nitroaromatics (e.g., din...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: Aerobic Bacteria: Under oxic conditions, many soil bacteria can initiate TNT degradation by partial reduction of its nitro groups or removal of nitrite. Notable examples include:
#
# • Pseudomonas spp.: ...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: Partial Oxidative Pathways: Although TNT’s nitro substituents strongly inhibit direct oxygenase attack, there are instances of cometabolic oxidation of TNT. One example is oxidation of the methyl grou...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • White-Rot Fungi (Basidiomycetes): Phanerochaete chrysosporium, a well-studied ligninolytic fungus, can mineralize a portion of TNT under nutrient-limited (lignin-degrading) conditions . Fungal TNT d...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: of part of the TNT molecule can proceed . Overall, this pathway highlights how some microbes use unusual enzymatic reactions to destabilize TNT’s ring, releasing nitrite as a nutrient and facilitating...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: 2. Cabrera, M.Á., Márquez, S.L., & Pérez-Donoso, J.M. (2022). Comparative genomic analysis of Antarctic Pseudomonas isolates with 2,4,6-trinitrotoluene transformation capabilities reveals their unique...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Old Yellow Enzyme (OYE) Family & Flavoprotein Reductases: Enzymes of the OYE family are broad-spectrum flavoprotein oxidoreductases that can attack nitroaromatic compounds in alternative ways. Sever...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: Key Intermediates and Fate: Across these pathways, the recurring intermediates are: hydroxylamino-dinitrotoluenes, amino-dinitrotoluenes (ADNTs), diaminonitrotoluenes (DANTs), and triaminotoluene (TAT...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: for further metabolism of TNT . Once a DNT or mononitrotoluene forms, bacteria can channel those into known catabolic pathways (many strains readily metabolize DNTs via dioxygenases that cleave the ri...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx

# %% [markdown]
# ### Conversational Chain (with ConversationBufferMemory)
# For follow‑up calls use the same qa_chain object, and the memory will automatically include everything you said before.
#
# If you want to start a brand‑new chat without creating a new chain object:
#
# `qa_chain.memory.clear()`   # wipes the stored chat_history
#
# Or just instantiate a fresh chain:
#
# ```
# qa_chain = local_rag_sys.build_qa_chain(
#     retriever_type="vec_semantic",
#     use_conversation=True,
# )
# ```

# %%
# Complete workflow with existing documents vector db, running QA-chain with a query to the model
# Build a conversational chain
qa_chain = local_rag_sys.build_qa_chain(retriever_type="vec_semantic", 
                                        use_conversation=True)
# Out:
# No split documents available for BM25Retriever creation. Need to build vector DB first.

# %%
# First turn
ans1 = qa_chain.invoke({"question": '''How does the SaProt protein-LLM differs from other protein-LLMs such as ESM-2? 
                        Use the given context (source documents) to answer the question.
                        Give the name of the source documents and metadata that supports your answer.'''})
print("\n🤖", ans1["answer"])

# Second turn – the model sees the previous answer in its context now
ans2 = qa_chain.invoke({"question": '''Two new protein LLMs models called: Diffusion Sequence Model (DSM) and xTrimoPGLM are suppose to be state-of-the-art. 
                        Compare them to the model you discussed in the previous prompt.
                        What are the key architectural novelties of these models?
                        Use the given context (source documents) to answer the question.
                        Give the name of the source documents and metadata that supports your answer. '''})
print("\n🤖", ans2["answer"])
# Out:
# 🤖 **How SaProt differs from other protein‑LLMs such as ESM‑2**
#
# | Aspect | SaProt (SaProt paper) | ESM‑2 (ESM family) |
# |--------|----------------------|--------------------|
# | **Vocabulary** | Uses a *structure‑aware (SA) vocabulary* that fuses the ordinary amino‑acid token with a Foldseek‑derived 3Di structural token at each position. The embedding layer therefore contains 441 tokens (21 residues × 21 structure symbols). | Uses only the conventional 20 residue tokens (plus special tokens). |
# | **Input representation** | Each protein is encoded as an *SA‑token sequence* (e.g., “s₁f₁, s₂f₂ …”), where the second component carries explicit 3‑D conformation information. | Input consists solely of the linear amino‑acid string; any structural signal must be inferred implicitly from the sequence. |
# | **Model size & architecture** | Identical transformer backbone and parameter count to ESM‑2 650M; the only architectural change is the expanded embedding matrix for the SA tokens. (SaProt “shares an identical network architecture, model size, and training examples with ESM‑2, with the key difference lying in its structure‑aware vocabulary.”) | Same transformer backbone but with the original residue‑only embedding layer. |
# | **Training data** | Pre‑trained on ~40 M proteins together with ∼40 M predicted structures from AlphaFoldDB (encoded by Foldseek). | Pre‑trained only on protein sequences (no explicit structural tokens). |
# | **Performance on structure‑related tasks** | Outperforms ESM‑2 in contact‑map prediction (Table 3: SaProt P@L = 86.15 vs 55.30 for short‑range contacts, etc.) and shows superior zero‑shot mutational‑effect scores (Table 1: ClinVar AUC 0.909 vs 0.862). | Lower scores on the same tasks. |
# | **Embedding geometry** | In t‑SNE visualisations of the SCOPe non‑redundant set, SaProt’s embeddings for α and β proteins are *separated* according to structure type, while ESM‑2’s embeddings are *intertwined*. (Figure 5 caption: “For the alpha and beta proteins, the representations generated by ESM‑2 are intertwined, whereas those generated by SaProt are separated based on structure type.”) | Same backbone but without explicit structural separation. |
#
# ### Source documents & metadata supporting the answer
#
# | # | Document (title) | Authors / Year | Relevant excerpt |
# |---|------------------|----------------|-----------------|
# | 1 | **“SaProt: Protein language modeling with structure‑aware vocabulary”** | Jin Su, Chenchen Han, Yuyang Zhou, Junjie Shan, Xibin Zhou, Fajie Yuan (2023) – bioRxiv | *“We introduce the concept of a ‘structure‑aware vocabulary’ that integrates residue tokens with structure tokens… SaProt shares an identical network architecture, model size, and training examples with ESM‑2, **with the key difference lying in its structure‑aware vocabulary**.”* |
# | 2 | Same SaProt paper (Section 3.1 & Figure 5) | — | *“For the alpha and beta proteins, the representations generated by **ESM‑2 are intertwined**, whereas those generated by **SaProt are separated based on structure type**.”* |
# | 3 | Same SaProt paper (Table 3) | — | *Contact‑map results: “SaProt 86.15 … vs ESM‑2 55.30” showing superior structural prediction.* |
# | 4 | Same SaProt paper (Table 1 & discussion) | — | *Zero‑shot mutational effect: “SaProt AUC 0.909 vs ESM‑2 0.862”* |
# | 5 | Same SaProt paper (Data description) | — | *“≈40 million protein sequences and structures… encoded by Foldseek into 3Di tokens, forming SA‑token sequences.”* |
#
# These excerpts collectively demonstrate that **SaProt’s main distinction from ESM‑2 is the incorporation of an explicit structure‑aware token vocabulary**, which allows it to ingest 3‑D structural information directly during pre‑training and leads to consistently better performance on tasks that depend on protein structure.
#
# 🤖 **Performance comparison**
#
# | Model | What the provided documents say about its performance | How it stacks up against **SaProt** |
# |-------|------------------------------------------------------|-----------------------------------|
# | **SaProt** | *“SaProt outperforms all residue‑sequence‑based and structure‑based models on both tasks”* (SaProt – Protein Language Modeling with Structure‑Aware Vocabulary, Westlake University) and “exhibits consistent improvement for predicting mutational effects … higher accuracy compared to MIF‑ST” (same source). | Baseline in the comparison – it is already state‑of‑the‑art among 35 M‑parameter PLMs that use only residue sequences. |
# | **Diffusion Sequence Model (DSM)** | *“DSM models match or outperform MLM‑based and discrete diffusion pLMs of the same size as well as an AR pLM almost twice DSM’s size”* (Diffusion Sequence Models for Enhanced Protein Representation and Generation, arXiv 2506.08293v1 9 Jun 2025).  <br> *“DSM650 produced the highest quality embeddings among similarly sized pLMs … only overtaken by the much larger ProtT5”* (same source). | DSM’s embeddings are **on par with or better than** those of SaProt for models of comparable size, and it even beats a much larger autoregressive model.  The paper does not give a direct head‑to‑head numeric comparison to SaProt, but the statements make clear that DSM reaches *similar* or *higher* representation quality while also adding strong generative abilities. |
# | **xTrimoPGLM** | *“xTrimoPGLM substantially outperforms other advanced baselines in 18 protein understanding benchmarks across four categories”* (xTrimoPGLM: unified 100‑billion‑parameter pretrained transformer for deciphering the language of proteins, Nature Methods Vol 22 May 2025). <br> *“xTrimoPGLM achieved a perplexity of 4.01 on CAMEO and 4.45 on CASP15, lower than ESMFold’s 5.21/6.18”* (same source). | With **100 B parameters**, xTrimoPGLM is far larger than SaProt (35–650 M) and therefore delivers higher absolute performance on a wide set of tasks. The document explicitly says it “substantially outperforms … baselines”, which include the ESM family that SaProt already beats, indicating that xTrimoPGLM exceeds SaProt’s performance when model scale is taken into account.
#
# **Design comparison**
#
# | Aspect | SaProt | DSM – what is new | xTrimoPGLM – what is new |
# |--------|--------|-------------------|--------------------------|
# | **Core architecture** | Uses the ESM‑2 transformer backbone (same size as the corresponding ESM model). | Extends the same ESM‑2 checkpoint but **adds a novel language‑modeling head** (extra linear layer, soft‑logit cap) and *ties* the final projection to the token‑embedding matrix. | A **unified transformer** of up to 100 B parameters that is trained jointly on two objectives (see below). |
# | **Input representation** | Introduces a **structure‑aware vocabulary** that concatenates residue tokens with Foldseek‑derived structure tokens, forming “SA‑tokens”. | Keeps the ordinary residue token space; the novelty lies in the **masked diffusion training objective**, not in new tokens. | Still works on plain amino‑acid sequences (no special SA‑vocab), but the model is designed to handle both *understanding* and *generation* tasks within a single network. |
# | **Training objective** | Standard masked language modeling (MLM) on the combined residue + structure token stream. | **Masked forward diffusion**: each training step randomly masks up to 90 % of tokens, then the model denoises them in a *single* forward pass. This enables “robust denoising across high corruption rates and sequence generation with global context” (Diffusion Sequence Models… arXiv 2506.08293v1). | **Curriculum‑style two‑phase pre‑training**: first 400 B tokens with pure MLM, then a second stage where *20 %* of batches use MLM and *80 %* use a generalized language modeling (GLM) objective, thereby unifying representation learning and autoregressive generation. |
# | **Generative capability** | Not designed for de‑novo sequence generation; focuses on representation quality. | Provides **unconditional generative sampling** that produces realistic protein sequences in one forward pass, matching natural amino‑acid k‑mer statistics and predicted structures/functions. | Supports both *de‑novo* and *conditional* design (e.g., binder generation) through the same model, leveraging its GLM head for autoregressive decoding. |
# | **Scale** | 35 M – 650 M parameters (the paper reports a 650 M version). | Same size as the underlying ESM‑2 checkpoint it extends (e.g., DSM‑150 M, DSM‑650 M). | 100 B parameters—two orders of magnitude larger than SaProt. |
#
# **Key architectural novelties**
#
# * **DSM**
#   * A **new language‑modeling head** (extra linear transformation + soft‑logit cap) tied to the embedding matrix (Diffusion Sequence Models…, arXiv 2506.08293v1).
#   * **Masked diffusion training** that treats masking as a forward diffusion process, allowing the model to denoise highly corrupted inputs and generate full sequences in one pass (same source).
#
# * **xTrimoPGLM**
#   * **Joint MLM + GLM pre‑training** with a curriculum that first minimizes MLM loss then blends 20 % MLM / 80 % GLM, enabling the same network to excel at both understanding and generation tasks (xTrimoPGLM…, Nature Methods Vol 22 May 2025).
#   * **Massive scale** (100 B parameters) combined with a unified objective, leading to lower perplexity on structure‑prediction benchmarks than dedicated PLMs such as ESMFold (same source).
#
# In summary, SaProt advances performance by enriching the token vocabulary with structural information while keeping a conventional MLM training regime. DSM builds on the same backbone but introduces a diffusion‑based denoising head that yields representations competitive with SaProt and adds strong generative power. xTrimoPGLM goes further in design by unifying two complementary language‑modeling objectives within an extremely large transformer, achieving substantially higher benchmark scores than both SaProt and DSM.

# %%
for doc in ans2['source_documents']:
    print(f"Content: {doc.page_content[:200]}...")
    print(f"Metadata title: {doc.metadata['source']}\n")
# Out:
# Content: process. DSM extends ESM2 ( 33) with a novel language modeling head and training objective, enabling robust denoising
# across high corruption rates and sequence generation with global context. After tr...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/Diffusion Sequence Models for Enhanced Protein Representation and Generation.pdf
#
# Content: arXiv:2506.08293v1  [q-bio.BM]  9 Jun 2025
# Diffusion Sequence Models for Enhanced Protein Representation and
# Generation
# Logan Hallee1, 2, Nikolaos Rafailidis1, David B. Bichara2, and Jason P. Gleghorn...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/Diffusion Sequence Models for Enhanced Protein Representation and Generation.pdf
#
# Content: embeddings and valuable downstream tasks (datasets described in Supplemental Figure S3). DSM650 produced the highest
# quality embeddings among similarly sized pLMs, generating consistently high F1 scor...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/Diffusion Sequence Models for Enhanced Protein Representation and Generation.pdf
#
# Content: • SaProt outperforms ESM-2 in all protein-level tasks. Specifically, SaProt shows remark-
# able enhancements over ESM-2 in the Thermostability, HumanPPI, Metal Ion Binding, and
# DeepLoc tasks. This outc...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/SaProt- Protein Language Modeling with Structure-aware Vocabulary.pdf
#
# Content: of objectives, which has led to a strategy for training xTrimoPGLM at an
# unprecedented scale of 100 billion parameters and 1 trillion training tokens. Our
# extensive experiments reveal that (1) xTrim...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/xTrimoPGLM- unified 100-billion-parameter pretrained transformer for deciphering the language of proteins.pdf
#
# Content: SAPROT: P ROTEIN LANGUAGE MODELING WITH
# STRUCTURE -AWARE VOCABULARY
# Jin Su, Chenchen Han, Yuyang Zhou, Junjie Shan, Xibin Zhou, Fajie Yuan∗
# Westlake University
# {sujin, hanchenchen, zhouyuyang, shanjun...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/SaProt- Protein Language Modeling with Structure-aware Vocabulary.pdf
#
# Content: tures. Through extensive evaluation, our SaProt model surpasses well-established
# and renowned baselines across 10 significant downstream tasks, demonstrating
# its exceptional capacity and broad applica...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/SaProt- Protein Language Modeling with Structure-aware Vocabulary.pdf
#
# Content: Like the ESM models, SaProt aims to contribute to the advancement of the biological community.
# This study has several limitations: (1) The performance of the proposed SA vocabulary heavily
# depends on ...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/SaProt- Protein Language Modeling with Structure-aware Vocabulary.pdf
#
# Content: non-redundant version (P IDE <40%) of the SCOPe (Chandonia et al., 2018) database. For the
# alpha and beta proteins, the representations generated by ESM-2 are intertwined, whereas those gen-
# erated by...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/SaProt- Protein Language Modeling with Structure-aware Vocabulary.pdf
#
# Content: the return (Fig. 1b). We speculate that protein sequences, unlike natural
# language, are less smooth in semantic space and more akin to a factual
# nature. Currently, PLM-based methods still struggle t...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/xTrimoPGLM- unified 100-billion-parameter pretrained transformer for deciphering the language of proteins.pdf
#
# Content: In summary, DSM closes the gap between understanding and creating proteins in a single architecture, enabled by a few
# Python line changes, providing a foundation for rapid, scalable, and biologically ...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/Diffusion Sequence Models for Enhanced Protein Representation and Generation.pdf
#
# Content: Nature Methods | Volume 22 | May 2025 | 1028–1039
#  1035
# Article https://doi.org/10.1038/s41592-025-02636-z
# test data performance. Thus, the performance of the test data suddenly
# increased, denoted as...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/xTrimoPGLM- unified 100-billion-parameter pretrained transformer for deciphering the language of proteins.pdf
#
# Content: ESM-2, given that residue-based PLMs also implicitly contain structure information (Rao et al.,
# 2020)? To answer it, we conduct an additional structure prediction task, namely contact map predic-
# tion...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/SaProt- Protein Language Modeling with Structure-aware Vocabulary.pdf
#
# Content: A C OMPARISON WITH PROST T5
# A very recent preprint in Heinzinger et al. (2023) proposed ProstT5 which pre-trains the protein
# language model (PLM) on a mixture of data of Foldseek token sequences and r...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/SaProt- Protein Language Modeling with Structure-aware Vocabulary.pdf
#
# Content: Nature Methods | Volume 22 | May 2025 | 1028–1039 1028
# nature methods
# Article
# https://doi.org/10.1038/s41592-025-02636-z
# xTrimoPGLM: unified 100-billion-parameter
# pretrained transformer for decipheri...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/xTrimoPGLM- unified 100-billion-parameter pretrained transformer for deciphering the language of proteins.pdf
#
# Content: Interestingly, the diffusion-based pLMs showcased a distinct sequence reconstruction scaling law that became clear when
# contrasting DSM and DPLM compared to ESM2 (Figure 4). Even at 90% masking, the d...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/Diffusion Sequence Models for Enhanced Protein Representation and Generation.pdf
#
# Content: 44. Xingyi Cheng, Bo Chen, Pan Li, Jing Gong, Jie Tang, and Le Song. Training compute-optimal protein language models. bioRxiv, 2024. doi: 10.1101/2024.06.06.597716.
# Pages: 2024.06.06.597716 Section: ...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/Diffusion Sequence Models for Enhanced Protein Representation and Generation.pdf
#
# Content: 4.1.3 R ESULTS
# Table 1 showcases the zero-shot results on the ProteinGym and ClinVar datasets. Based on the
# results, we draw several noteworthy conclusions:
# • SaProt outperforms all residue sequence-b...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/SaProt- Protein Language Modeling with Structure-aware Vocabulary.pdf
#
# Content: Model ClinVar ProteinGym
# w/o MSA retrieval w/ MSA retrieval
# AUC Spearman’s ρ Spearman’s ρ
# ESM-2 (15B) 0.843 0.436 0.479
# SaProt 0.909 0.478 0.489
# Table 6: Zero-shot comparison with ESM-2 15B version. C...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/SaProt- Protein Language Modeling with Structure-aware Vocabulary.pdf
#
# Content: while CASP15 consists of 56 publicly available proteins (released in
# May 2022). Initially, we observed the perplexity (the lower the better)
# of these two datasets in PLMs, which served as the back...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/xTrimoPGLM- unified 100-billion-parameter pretrained transformer for deciphering the language of proteins.pdf
#
# Content: suffix supports both de novo and conditional protein design through sequence
# generation. b, xTrimoPGLM shows lower perplexity than other leading PLMs like
# ESM2 and ProGen2-xlarge in evaluations on t...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/xTrimoPGLM- unified 100-billion-parameter pretrained transformer for deciphering the language of proteins.pdf
#
# Content: Model ClinV
# ar ProteinGym(w/o MSA retrieval) DeepLoc
# Subcellular
# Binary
# A
# UC Spearman’s ρ Acc% Acc%
# Ev
# oformer-inspired ESM(35M) 0.589
# 0.178 66.11 89.25
# MIF 0.638
# 0.256 61.90 85.90
# SaProt(35M) 0.754
# 0...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/SaProt- Protein Language Modeling with Structure-aware Vocabulary.pdf
#
# Content: quence, serving as the input for existing residue-based PLMs. Through unsupervised training on
# massive protein SA-token sequences, we obtain a Structure-aware Protein language model named
# SaProt. To a...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/SaProt- Protein Language Modeling with Structure-aware Vocabulary.pdf
#
# Content: summary, while scaling single-sequence models enhances the perfor-
# mance, it still struggles with OOD data, which is effectively addressed
# by MSA-based augmentation.
# Evaluation of protein sequence ge...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/xTrimoPGLM- unified 100-billion-parameter pretrained transformer for deciphering the language of proteins.pdf
#
# Content: allows for seamless integration with advances in large-scale foundation AI models, such as
# BERT (Devlin et al., 2018), BART (Lewis et al., 2019), GPT (Brown et al., 2020), etc.
# • By utilizing the SA-t...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/SaProt- Protein Language Modeling with Structure-aware Vocabulary.pdf
#
# Content: advancement in the field of protein language modeling.
# Evaluation of protein structure prediction
# Protein sequences encode rich information about their 3D structures
# and function through evolutionary...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/xTrimoPGLM- unified 100-billion-parameter pretrained transformer for deciphering the language of proteins.pdf
#
# Content: For DSM pretaining, we used OMG prot50, a protein-only dataset containing over 207
# million sequences after clustering the Open MetaGenomic dataset (OMG) at 50% sequence
# identity (36). We randomly remo...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/Diffusion Sequence Models for Enhanced Protein Representation and Generation.pdf
#
# Content: for predicting subsequent words, the prefix-encoding portion
# remains bidirectional.
# The framework of xTrimoPGLM, along with its application in down-
# stream tasks, is depicted in Fig. 1a. Motivated by...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/xTrimoPGLM- unified 100-billion-parameter pretrained transformer for deciphering the language of proteins.pdf
#
# Content: We compare SaProt with two types of baselines: sequence-based models and structure-based mod-
# els. For sequence-based models, we include ESM-1b (Rives et al., 2019), ESM-1v (Meier et al.,
# 2021) (the r...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/SaProt- Protein Language Modeling with Structure-aware Vocabulary.pdf
#
# Content: Proteins play vital roles in the sustenance, growth and defense mecha-
# nisms of living organisms. They provide structural support for many
# essential biological processes such as synthesizing enzymes,...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/pdfs/xTrimoPGLM- unified 100-billion-parameter pretrained transformer for deciphering the language of proteins.pdf

# %%
# First turn
ans1 = qa_chain.invoke({"question": '''Summarize the main group of TNT degrading microbial species, separate into Aerobic vs. Anaerobic bacteria, what are the main differences? 
                        Use the given context (source documents) to answer the question.
                        Give the name of the source documents and metadata that supports your answer.'''})
print("\n🤖", ans1["answer"])

# Second turn – the model sees the previous answer in its context now
ans2 = qa_chain.invoke({"question": '''What are the main genes and enzymes involved in TNT degradation of the Aerobic vs. Anaerobic bacteria that you have summarized? 
                        Use the given context (source documents) to answer the question.
                        Give the name of the source documents and metadata that supports your answer. '''})
print("\n🤖", ans2["answer"])
# Out:
# 🤖 **Summary of the main groups of TNT‑degrading microbes (bacteria)**
#
# | **Category** | **Typical genera / species mentioned in the source material** | **Characteristic metabolic features** |
# |--------------|---------------------------------------------------------------|---------------------------------------|
# | **Aerobic bacteria** | • *Pseudomonas* spp. (e.g., *P. fluorescens*, *P. putida*, strain IIBx)  <br>• *Bacillus* spp.<br>• *Staphylococcus* spp.<br>• *Mycobacterium* spp.<br>• *Rhodococcus* spp.<br>• *Serratia marcescens*<br>• *Stenotrophomonas* isolates | – Operate under oxic conditions. <br>– Primary route is **nitro‑group reduction** (NO₂ → NO → NHOH → NH₂) producing hydroxylamino‑ and amino‑dinitrotoluenes (ADNTs, DANTs). <br>– Some strains can form **Meisenheimer complexes** that eject nitrite, yielding dinitrotoluene (DNT) which can then be attacked by dioxygenases. <br>– Generally stop at partially reduced intermediates (ADNT, azoxy dimers); complete mineralisation of the aromatic ring is rare in a single aerobic isolate. <br>– Often use TNT only as a **nitrogen source**; carbon from the toluene moiety may be further degraded if DNT is formed. |
# | **Anaerobic bacteria** | • *Veillonella alkalescens*<br>• *Escherichia coli* (facultative, under strict anoxia)<br>• *Clostridium* spp. (e.g., *C. bifermentans*, *C. acetobutylicum*, *C. pasterianum*, *C. sordellii*)<br>• *Desulfovibrio* spp.<br>• *Methanococcus* spp. | – Operate in the **absence of O₂** (strict anaerobes or facultatives under anoxic conditions). <br>– Carry out a **full six‑electron reduction** of each nitro group, ultimately converting TNT → 2,4,6‑triaminotoluene (**TAT**). <br>– Reduction proceeds through nitroso and hydroxylamino intermediates; the process is often coupled to **fermentation or anaerobic respiration**, sometimes using TNT as a terminal electron acceptor. <br>– TAT is relatively stable under anoxia but can polymerise/oxidise when exposed to O₂; further degradation of the aromatic ring is rarely observed, so the pathway mainly detoxifies TNT by removing nitro groups. |
#
# ### Main Differences between Aerobic and Anaerobic TNT‑degrading bacteria
#
# | Aspect | Aerobic bacteria | Anaerobic bacteria |
# |--------|-------------------|--------------------|
# | **Electron acceptor** | O₂; reactions are generally reductive but occur in the presence of oxygen. | No O₂; reduction uses H₂, NAD(P)H, or other internal electron donors; some use TNT itself as an electron sink/terminal electron acceptor. |
# | **Extent of nitro‑group removal** | Usually **partial**: 1–2 nitro groups are reduced; ADNTs/DANTs accumulate. Full three‑nitro reduction is rare. | Typically **complete**: all three nitro groups are reduced, yielding TAT. |
# | **Aromatic‑ring fate** | Limited ring attack; Meisenheimer complex formation can lead to denitration (producing DNT) which may be further oxidised by dioxygenases, but full mineralisation is uncommon. | Ring remains largely intact after nitro reduction; TAT does not undergo efficient oxidative cleavage under anoxia. |
# | **Typical metabolic outcome** | Production of toxic or recalcitrant amino‑nitrotoluene intermediates and azoxy polymers; often used only for nitrogen acquisition. | Detoxification by converting the explosive nitro groups to amines; energy gain is modest (often coupled to fermentative metabolism). |
# | **Representative genera** | *Pseudomonas*, *Bacillus*, *Rhodococcus*, *Mycobacterium*, *Serratia* etc. | *Clostridium*, *Veillonella*, *Desulfovibrio*, *Methanococcus*, facultative *E. coli*. |
# | **Environmental application** | Often employed in **aerobic polishing stages** after an anaerobic reduction step to degrade the resulting DNT/ADNT intermediates. | Used in **anaerobic pre‑treatment** (e.g., bioreactors, sediment zones) to eliminate nitro groups and lower explosive toxicity before an aerobic phase. |
#
# ---
#
# ## Source Documents & Metadata Supporting This Answer
#
# | # | Document / Section (as presented in the provided context) | Type of information used |
# |---|-----------------------------------------------------------|--------------------------|
# | 1 | **Scope of Document** – “This document provides a comprehensive analysis of microbial TNT degradation.” | General framing that the text is a review of microbial TNT degraders. |
# | 2 | **TNT‑Degrading Microbial Species** (section) | Lists aerobic bacteria (*Pseudomonas*, *Bacillus*, etc.) and anaerobic organisms (*Veillonella*, *Clostridium*, *Desulfovibrio*), describing their transformations. |
# | 3 | **Multi‑Omics Approaches and Systems Biology Insights** – subsections on *Clostridium spp.* and other aerobes | Provides details on anaerobic complete reduction to TAT versus aerobic partial reductions (ADNT, DANT). |
# | 4 | **Genomic Insights: Key Genes and Enzymes** – “Nitroreductases (Type I)” & “Azoreductases” | Describes enzymatic mechanisms typical of aerobic nitro‑group reduction. |
# | 5 | **Anaerobic Degradation Routes** (paragraphs) | Explicit description of full six‑electron reductions, production of TAT, and use of TNT as a terminal electron acceptor. |
# | 6 | **References – Ramos J.L. et al. (2001)** “Biological degradation of 2,4,6‑trinitrotoluene (TNT).” | Primary literature source that historically documents both aerobic and anaerobic degraders. |
# | 7 | **Cabrera M.A. et al. (2022 & 2024)** – comparative genomics of Antarctic *Pseudomonas* isolates | Supports the identification of aerobic *Pseudomonas* species with high xenobiotic‑degrading gene content. |
# | 8 | **Liao H.Y. et al. (2018)** – transcriptomic & proteomic analysis of *Citrobacter* sp. | Provides evidence for nitroreductase‐driven aerobic TNT transformation. |
# | 9 | **Ziganshin A.M. et al. (2007)** – hydride‑mediated reduction by yeasts (included to contrast bacterial pathways) | Highlights that anaerobic bacteria achieve full nitro reduction, while yeasts use a different mechanism; reinforces the bacterial distinction. |
# |10| **EAWAG‑BBD (1999)** “2,4,6‑Trinitrotoluene Degradation Pathway (Aerobic and Anaerobic).” | External database summarising both aerobic and anaerobic routes, corroborating the differences outlined above. |
#
# *All statements in the answer are directly drawn from these sections of the supplied context; no external knowledge was introduced.*
#
# 🤖 **Aerobic bacteria – principal TNT‑degrading genes / enzymes**
#
# | Gene / enzyme (function) | What it does in the TNT pathway | Source(s) that mention it |
# |---------------------------|--------------------------------|----------------------------|
# | **Type I nitroreductases** (e.g. *nfsA*, *nfsB*) | Two‑electron FMN/FAD‑dependent reduction of a nitro group to nitroso → hydroxylamino → amine; the first entry step for most aerobic degraders. | “Genomic Insights: Key Genes and Enzymes” – description of Type I nitroreductases; also cited in the *Metabolic Pathways of TNT Degradation* section. |
# | **nemA** (N‑ethylmaleimide reductase) | Reduces TNT to 4‑ADNT and 2‑ADNT; identified as the most up‑regulated gene in a Citrobacter sp. TNT degrader. | “Metabolic Pathways of TNT Degradation” – paragraph on Nitroreductases (Type I). |
# | **Azoreductase** (azoreductase‑encoding gene) | Highly induced (>1 000‑fold) during TNT exposure; can reduce nitro‑aromatics or hydroxylamine intermediates, acting as a key TNT‑transforming enzyme in *Pseudomonas* sp. TNT3. | “Genomic Insights: Key Genes and Enzymes” (Azoreductases paragraph) and the transcriptomic study of *Pseudomonas* sp. TNT3 under “Aerobic Bacteria”. |
# | **Old Yellow Enzyme (OYE) family reductases** (oxygen‑insensitive nitroreductases) | Catalyze hydride transfer that generates Meisenheimer σ‑complexes, leading to nitrite release and denitration of TNT. | “Genomic Insights: Key Genes and Enzymes” – mention of OYEs; also in the “Metabolic Pathways” discussion of hydride‑mediated reduction. |
# | **PETN reductase** (pentaerythritol tetranitrate reductase) | NADPH‑dependent enzyme that attacks TNT’s aromatic ring, forming mono‑ and di‑hydride Meisenheimer complexes; releases nitrite. | “Aerobic Bacteria” – description of *Enterobacter cloacae* PB2. |
# | **Flavoprotein reductases** (general flavoproteins in *Pseudomonas fluorescens*) | Reduce TNT to hydroxylamino‑ and amino‑dinitrotoluenes; also can mediate ring hydrogenation to Meisenheimer complexes. | “Aerobic Bacteria” – paragraph on *Pseudomonas* spp. |
# | **Efflux pumps & stress‑response enzymes** (e.g., superoxide dismutase, peroxidases) | Not catalytic for TNT itself but essential for tolerance and allowing the catabolic enzymes to function. | “Multi‑Omics Approaches and Systems Biology Insights” – list of accessory/regulatory genes. |
#
# **Anaerobic bacteria – principal TNT‑degrading genes / enzymes**
#
# | Gene / enzyme (function) | What it does in the TNT pathway | Source(s) that mention it |
# |---------------------------|--------------------------------|----------------------------|
# | **Oxygen‑insensitive nitroreductases** (same families as aerobic, but operating under anoxic conditions) | Carry out stepwise six‑electron reductions of each –NO₂ to –NH₂, producing triaminotoluene (TAT). | “Anaerobic Bacteria” sections describing Veillonella, *Clostridium* spp., Desulfovibrio spp.; also the general nitroreductase discussion in “Genomic Insights”. |
# | **Nitrite reductase (NasB)** & associated high‑affinity nitrite uptake systems | Assimilate nitrite released from TNT denitration and reduce it to ammonia for biomass synthesis; links TNT reduction to growth on nitrogen. | “Anaerobic Bacteria” – paragraph on *Pseudomonas putida* JLR11’s nitrite uptake/NasB system; also in “Nitrite Reductases and Assimilatory Enzymes”. |
# | **Hydrogenases / H₂‑oxidizing enzymes** (implicit in Clostridial/Veillonella metabolism) | Provide the strong reducing power needed for the six‑electron reductions of nitro groups under strict anaerobic conditions. | “Anaerobic Bacteria” – description of *Clostridium* spp. using H₂ as electron donor to fully reduce TNT. |
# | **Bamberger‑rearrangement enzymes / aminophenol‑forming activities** (not named, but implied) | Convert hydroxylamino‑dinitrotoluene intermediates into aminophenols after anaerobic reduction. | “Anaerobic Bacteria” – discussion of Clostridial pathways that generate aminophenols via Bamberger rearrangement. |
# | **General stress‑response and DNA‑repair proteins** (e.g., nitric‑oxide dioxygenase) | Protect cells from nitrosative damage generated during anaerobic TNT reduction; essential for survival but not directly catabolic. | “Multi‑Omics Approaches” – list of nitrosative‑stress genes up‑regulated in TNT‑challenged microbes. |
#
# **Documents & metadata that support the answer**
#
# | Information extracted | Document / section title (as given) | Reference/metadata |
# |----------------------|-------------------------------------|--------------------|
# | Description of Type I nitroreductases, *nfsA/nfsB* and their role in TNT reduction | “Genomic Insights: Key Genes and Enzymes” – Nitroreductases paragraph; also under “Metabolic Pathways of TNT Degradation”. | No formal citation number; part of the main body. |
# | *nemA* (N‑ethylmaleimide reductase) activity on TNT | Same “Metabolic Pathways of TNT Degradation” section. | – |
# | Azoreductase gene highly induced in *Pseudomonas* sp. TNT3 | “Genomic Insights: Key Genes and Enzymes” (Azoreductases paragraph) and the transcriptomic study of *Pseudomonas* sp. TNT3 under “Aerobic Bacteria”. | – |
# | OYE family enzymes mediating hydride addition/Meisenheimer complexes | “Genomic Insights: Key Genes and Enzymes”; also in the pathway discussion (“Metabolic Pathways”). | – |
# | PETN reductase (pentaerythritol tetranitrate reductase) from *Enterobacter cloacae* PB2 | “Aerobic Bacteria” – paragraph on Enterobacteriaceae. | – |
# | Flavoprotein enzymes in *Pseudomonas fluorescens* | “Aerobic Bacteria” – description of Pseudomonas spp. | – |
# | Accessory genes (efflux pumps, oxidative‑stress enzymes) | “Multi‑Omics Approaches and Systems Biology Insights”. | – |
# | Anaerobic complete reduction to TAT by Veillonella, *Clostridium*, Desulfovibrio | “Anaerobic Bacteria” sections (multiple paragraphs). | – |
# | Nitrite reductase NasB & uptake system in *Pseudomonas putida* JLR11 | “Anaerobic Bacteria” – paragraph on nitrite assimilation; also referenced under “Nitrite Reductases and Assimilatory Enzymes”. | – |
# | Hydrogen‑dependent reduction in Clostridia | “Anaerobic Bacteria” – description of H₂ as electron donor. | – |
# | Bamberger rearrangement / aminophenol formation in anaerobes | “Anaerobic Bacteria” – discussion of Clostridial pathways. | – |
# | General stress‑response genes (nitrosative, oxidative) in TNT‑exposed microbes | “Multi‑Omics Approaches and Systems Biology Insights”. | – |
#
# All statements above are drawn **exclusively** from the supplied source material; no external knowledge has been added.

# %%
for doc in ans2['source_documents']:
    print(f"Content: {doc.page_content[:200]}...")
    print(f"Metadata title: {doc.metadata['source']}\n")
# Out:
# Content: Scope of Document: This document provides a comprehensive analysis of microbial TNT degradation. We first catalog the known TNT-degrading species across bacteria, fungi, and yeasts, highlighting their...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: Genomic Insights: Key Genes and Enzymes
#
#
#
# Microbial TNT degradation relies on a suite of specialized enzymes that initiate TNT transformation despite its inert aromatic structure. Genomic and biochem...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: Comparative Genomic Insights: Genome sequencing of TNT-degrading strains has shed light on their evolutionary adaptations. For example, three Antarctic Pseudomonas isolates (TNT3, TNT11, TNT19) were s...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Azoreductases: An unexpected finding from genomic studies is the involvement of azoreductase enzymes in TNT degradation. Azoreductases normally reduce azo bonds (–N=N–) in dyes, but some can also re...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: In summary, the genetic toolkit for TNT biodegradation comprises mostly reductive enzymes that either remove nitro groups or destabilize the aromatic ring, along with supporting systems to manage stre...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: Genomic and Metabolic Insights into Microbial Biodegradation of TNT
#
#
#
# Abstract...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Nitroreductases (Type I): A common entry point for TNT metabolism is the stepwise reduction of nitro (-NO₂) groups to nitroso (-NO), hydroxylamino (-NHOH), and amino (-NH₂) groups. These reactions a...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: In summary, TNT degradation pathways are complex and can follow multiple routes depending on the organism and conditions. Aerobic processes excel at initial transformations and co-metabolic turnover o...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Accessory and Regulatory Genes: Alongside catabolic enzymes, microbes possess regulatory and support genes that enable TNT degradation. These include: (1) oxidative stress response genes – TNT redox...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: Aerobic Bacteria: Under oxic conditions, many soil bacteria can initiate TNT degradation by partial reduction of its nitro groups or removal of nitrite. Notable examples include:
#
# • Pseudomonas spp.: ...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Transcriptomic Profiling: Genome-wide RNA expression analyses reveal which genes are turned on or off in the presence of TNT. A recent study examined the transcriptome of Pseudomonas sp. TNT3 (an An...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: In summary, omics studies have expanded our understanding from individual enzymes to the global response of microorganisms to TNT. They reveal that TNT degradation is an orchestrated event involving s...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Other Anaerobes: Veillonella alkalescens was one of the first organisms noted to reduce TNT to TAT under strictly anaerobic conditions. Even Escherichia coli (facultative anaerobe) can perform compl...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: 7. Hannink, N.K., et al. (2001). Phytodetoxification of TNT by transgenic plants expressing a bacterial nitroreductase. Nature Biotechnology, 19(12): 1168–1172 .
#
# 8. Duque, E., et al. (1993). Identifi...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: Abstract
#
# 2,4,6-Trinitrotoluene (TNT) is a recalcitrant explosive pollutant whose breakdown in the environment is facilitated by diverse microbes. This document summarizes key findings on TNT biodegra...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Systems Biology and Modeling: With large omics datasets, scientists have begun constructing regulatory and metabolic network models for TNT-degrading organisms. For instance, integrating the transcr...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Functional Genomics: Another omics-related approach is random mutagenesis or knockout studies combined with sequencing to find genes essential for TNT metabolism. Transposon mutagenesis, for instanc...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: . These azoxy compounds are intensely colored, highly recalcitrant, and represent dead-end immobilization products in many TNT-fed cultures . In summary, aerobic nitro-reduction rapidly eliminates TNT...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: Microbial Bioremediation: The use of microorganisms to detoxify and remove TNT from the environment offers a promising alternative to costly physicochemical cleanup methods . Certain bacteria and fung...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: Complete Reduction (Anaerobic Pathway): In oxygen-free environments, TNT can be fully reduced to TAT (2,4,6-triaminotoluene) by certain bacteria. This occurs via sequential addition of six electrons (...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Clostridium spp.: These obligate anaerobes are among the most effective TNT degraders in anoxic conditions. Clostridium bifermentans strains transform TNT through successive reductions to diaminonit...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: to its electron transport chain, certain metabolic pathways, and motility functions during TNT exposure. This likely reflects a shift to a slower-growing, stress-resistant state: the bacterium conserv...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Enterobacteriaceae: Enterobacter cloacae PB2 is capable of denitrating TNT. It reduces TNT via formation of a Meisenheimer complex and releases nitrite . An NADPH-dependent enzyme called pentaerythr...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Other Aerobes: Bacillus and Staphylococcus species can reduce TNT, typically to monoamino dinitrotoluene (e.g., 2-amino-4,6-dinitrotoluene) with nitrite release. Mycobacterium and Rhodococcus (Gram-...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: 2. Cabrera, M.Á., Márquez, S.L., & Pérez-Donoso, J.M. (2022). Comparative genomic analysis of Antarctic Pseudomonas isolates with 2,4,6-trinitrotoluene transformation capabilities reveals their unique...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Metabolomics and Pathway Confirmation: While less reported than transcript/proteome data, metabolomic analyses (identifying intermediate compounds) and isotope tracing have been used to confirm TNT ...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Dioxygenases and Ring-Cleavage Enzymes: Direct oxidative ring cleavage of TNT is very challenging due to its electron-poor ring, and no dedicated TNT dioxygenase has been identified. However, once T...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Sulfate-Reducers: Desulfovibrio species can anaerobically respire TNT. For example, Desulfovibrio sp. strain B uses TNT as a nitrogen source and may produce toluene as a downstream product . Other D...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: • Nitrite Reductases and Assimilatory Enzymes: Though not directly modifying TNT, enzymes like assimilatory nitrite reductase (NasB) and ammonium-assimilating enzymes (e.g., glutamine synthetase) are ...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
#
# Content: Anaerobic Degradation Routes: In oxygen-free environments, TNT undergoes more complete reduction. The hallmark of anaerobic TNT metabolism is the production of triaminotoluene (TAT). This results from...
# Metadata title: /Users/danid/Downloads/RAG_personal_knowledge_base/new_docs_to_add/Genomic and Metabolic Insights into Microbial Biodegradation of TNT.docx
